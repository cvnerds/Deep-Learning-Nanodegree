# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 0 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    return x/255.0


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
mymap = np.eye(10)

def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    res = np.empty((len(x), 10))
    for i,val in enumerate(x):
        res[i] = mymap[val]
    return res


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a bach of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, shape=(None,)+image_shape, name='x')


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, shape=(None,n_classes), name='y')


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, shape=None, name='keep_prob')


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    weight = tf.Variable(tf.truncated_normal([conv_ksize[0], conv_ksize[1], x_tensor.get_shape().as_list()[3], conv_num_outputs], stddev=0.1))
    bias = tf.Variable(tf.zeros(conv_num_outputs))
    conv_layer = tf.nn.conv2d(x_tensor, weight, strides=[1, conv_strides[0], conv_strides[1], 1], padding='SAME')
    conv_layer = tf.nn.bias_add(conv_layer, bias)
    conv_layer = tf.nn.relu(conv_layer)
    conv_layer = tf.nn.max_pool(conv_layer, ksize=[1, pool_ksize[0], pool_ksize[1], 1], strides=[1, pool_strides[0], pool_strides[1], 1], padding='SAME')
    return conv_layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    shape = x_tensor.get_shape().as_list()
    return tf.reshape(x_tensor, shape=[-1, shape[1]*shape[2]*shape[3]])


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    num_inputs = x_tensor.shape.as_list()[1]
    weights  = tf.Variable(tf.truncated_normal([num_inputs, num_outputs], stddev=0.1))
    bias     = tf.Variable(tf.zeros(num_outputs))
    
    fc_layer = tf.reshape(x_tensor, [-1, num_inputs])
    fc_layer = tf.add(tf.matmul(fc_layer, weights), bias)
    fc_layer = tf.nn.relu(fc_layer)
    
    return fc_layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    num_inputs = x_tensor.shape.as_list()[1]
    weights  = tf.Variable(tf.truncated_normal([num_inputs, num_outputs], stddev=0.1))
    bias     = tf.Variable(tf.zeros(num_outputs))
    
    out_layer = tf.reshape(x_tensor, [-1, num_inputs])
    out_layer = tf.add(tf.matmul(out_layer, weights), bias)
    
    return out_layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    
    x_tensor=conv2d_maxpool(x,         64, conv_ksize=(4,4), conv_strides=(2,2), pool_ksize=(4,4), pool_strides=(2,2))
    x_tensor=conv2d_maxpool(x_tensor, 128, conv_ksize=(4,4), conv_strides=(2,2), pool_ksize=(4,4), pool_strides=(2,2))
    x_tensor=conv2d_maxpool(x_tensor, 256, conv_ksize=(4,4), conv_strides=(2,2), pool_ksize=(4,4), pool_strides=(2,2))
    
    # TODO: Apply a Flatten Layer
    x_tensor = flatten(x_tensor)
    
    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    x_tensor = fully_conn(x_tensor, num_outputs=1024)
    x_tensor = tf.contrib.layers.dropout(x_tensor, keep_prob)
    x_tensor = fully_conn(x_tensor, num_outputs=512)
    x_tensor = tf.contrib.layers.dropout(x_tensor, keep_prob)
    x_tensor = fully_conn(x_tensor, num_outputs=256)
    x_tensor = tf.contrib.layers.dropout(x_tensor, keep_prob)
        
    # TODO: Apply an Output Layer
    x_tensor = output(x_tensor, 10)
    
    # TODO: return output
    return x_tensor


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
init = tf.global_variables_initializer()

def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer, feed_dict={x: feature_batch, y: label_batch, keep_prob:keep_probability})

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    loss = session.run(cost, feed_dict={
                x: feature_batch,
                y: label_batch,
                keep_prob: 1.})
    valid_acc = session.run(accuracy, feed_dict={
                x:valid_features,
                y:valid_labels,
                keep_prob: 1.})

    print('Loss: {:>10.4f}, Validation Accuracy: {:.6f}'.format(loss, valid_acc))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 200
batch_size = 4096
keep_probability = 0.5

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Loss:     2.3593, Validation Accuracy: 0.123400
# Epoch  2, CIFAR-10 Batch 1:  Loss:     2.2760, Validation Accuracy: 0.138000
# Epoch  3, CIFAR-10 Batch 1:  Loss:     2.2819, Validation Accuracy: 0.151000
# Epoch  4, CIFAR-10 Batch 1:  Loss:     2.2848, Validation Accuracy: 0.155200
# Epoch  5, CIFAR-10 Batch 1:  Loss:     2.2809, Validation Accuracy: 0.150600
# Epoch  6, CIFAR-10 Batch 1:  Loss:     2.2726, Validation Accuracy: 0.143200
# Epoch  7, CIFAR-10 Batch 1:  Loss:     2.2588, Validation Accuracy: 0.157800
# Epoch  8, CIFAR-10 Batch 1:  Loss:     2.2398, Validation Accuracy: 0.157800
# Epoch  9, CIFAR-10 Batch 1:  Loss:     2.2134, Validation Accuracy: 0.165200
# Epoch 10, CIFAR-10 Batch 1:  Loss:     2.1821, Validation Accuracy: 0.178800
# Epoch 11, CIFAR-10 Batch 1:  Loss:     2.1349, Validation Accuracy: 0.182600
# Epoch 12, CIFAR-10 Batch 1:  Loss:     2.1053, Validation Accuracy: 0.194400
# Epoch 13, CIFAR-10 Batch 1:  Loss:     2.0520, Validation Accuracy: 0.211400
# Epoch 14, CIFAR-10 Batch 1:  Loss:     2.0102, Validation Accuracy: 0.222800
# Epoch 15, CIFAR-10 Batch 1:  Loss:     1.9622, Validation Accuracy: 0.224800
# Epoch 16, CIFAR-10 Batch 1:  Loss:     1.9068, Validation Accuracy: 0.241000
# Epoch 17, CIFAR-10 Batch 1:  Loss:     1.8676, Validation Accuracy: 0.252800
# Epoch 18, CIFAR-10 Batch 1:  Loss:     1.8362, Validation Accuracy: 0.273600
# Epoch 19, CIFAR-10 Batch 1:  Loss:     1.8196, Validation Accuracy: 0.265400
# Epoch 20, CIFAR-10 Batch 1:  Loss:     1.8101, Validation Accuracy: 0.263000
# Epoch 21, CIFAR-10 Batch 1:  Loss:     1.7530, Validation Accuracy: 0.287200
# Epoch 22, CIFAR-10 Batch 1:  Loss:     1.7375, Validation Accuracy: 0.300800
# Epoch 23, CIFAR-10 Batch 1:  Loss:     1.6926, Validation Accuracy: 0.315800
# Epoch 24, CIFAR-10 Batch 1:  Loss:     1.6532, Validation Accuracy: 0.316400
# Epoch 25, CIFAR-10 Batch 1:  Loss:     1.6275, Validation Accuracy: 0.320400
# Epoch 26, CIFAR-10 Batch 1:  Loss:     1.6037, Validation Accuracy: 0.321000
# Epoch 27, CIFAR-10 Batch 1:  Loss:     1.5859, Validation Accuracy: 0.315800
# Epoch 28, CIFAR-10 Batch 1:  Loss:     1.5608, Validation Accuracy: 0.331200
# Epoch 29, CIFAR-10 Batch 1:  Loss:     1.5307, Validation Accuracy: 0.350000
# Epoch 30, CIFAR-10 Batch 1:  Loss:     1.4994, Validation Accuracy: 0.353800
# Epoch 31, CIFAR-10 Batch 1:  Loss:     1.4788, Validation Accuracy: 0.356000
# Epoch 32, CIFAR-10 Batch 1:  Loss:     1.4618, Validation Accuracy: 0.364200
# Epoch 33, CIFAR-10 Batch 1:  Loss:     1.4459, Validation Accuracy: 0.376600
# Epoch 34, CIFAR-10 Batch 1:  Loss:     1.3876, Validation Accuracy: 0.377200
# Epoch 35, CIFAR-10 Batch 1:  Loss:     1.3658, Validation Accuracy: 0.368600
# Epoch 36, CIFAR-10 Batch 1:  Loss:     1.3369, Validation Accuracy: 0.387200
# Epoch 37, CIFAR-10 Batch 1:  Loss:     1.3825, Validation Accuracy: 0.374600
# Epoch 38, CIFAR-10 Batch 1:  Loss:     1.3158, Validation Accuracy: 0.388800
# Epoch 39, CIFAR-10 Batch 1:  Loss:     1.2568, Validation Accuracy: 0.405200
# Epoch 40, CIFAR-10 Batch 1:  Loss:     1.2653, Validation Accuracy: 0.413200
# Epoch 41, CIFAR-10 Batch 1:  Loss:     1.2067, Validation Accuracy: 0.410400
# Epoch 42, CIFAR-10 Batch 1:  Loss:     1.1538, Validation Accuracy: 0.425800
# Epoch 43, CIFAR-10 Batch 1:  Loss:     1.1399, Validation Accuracy: 0.431000
# Epoch 44, CIFAR-10 Batch 1:  Loss:     1.0995, Validation Accuracy: 0.429000
# Epoch 45, CIFAR-10 Batch 1:  Loss:     1.1003, Validation Accuracy: 0.427000
# Epoch 46, CIFAR-10 Batch 1:  Loss:     1.0451, Validation Accuracy: 0.436400
# Epoch 47, CIFAR-10 Batch 1:  Loss:     1.0381, Validation Accuracy: 0.443200
# Epoch 48, CIFAR-10 Batch 1:  Loss:     0.9947, Validation Accuracy: 0.444000
# Epoch 49, CIFAR-10 Batch 1:  Loss:     0.9607, Validation Accuracy: 0.450600
# Epoch 50, CIFAR-10 Batch 1:  Loss:     0.9334, Validation Accuracy: 0.453800
# Epoch 51, CIFAR-10 Batch 1:  Loss:     0.9007, Validation Accuracy: 0.454800
# Epoch 52, CIFAR-10 Batch 1:  Loss:     0.8966, Validation Accuracy: 0.460600
# Epoch 53, CIFAR-10 Batch 1:  Loss:     0.8734, Validation Accuracy: 0.458600
# Epoch 54, CIFAR-10 Batch 1:  Loss:     0.8372, Validation Accuracy: 0.462800
# Epoch 55, CIFAR-10 Batch 1:  Loss:     0.8206, Validation Accuracy: 0.458600
# Epoch 56, CIFAR-10 Batch 1:  Loss:     0.7813, Validation Accuracy: 0.459600
# Epoch 57, CIFAR-10 Batch 1:  Loss:     0.7469, Validation Accuracy: 0.461600
# Epoch 58, CIFAR-10 Batch 1:  Loss:     0.7395, Validation Accuracy: 0.473400
# Epoch 59, CIFAR-10 Batch 1:  Loss:     0.7777, Validation Accuracy: 0.455400
# Epoch 60, CIFAR-10 Batch 1:  Loss:     0.7021, Validation Accuracy: 0.469800
# Epoch 61, CIFAR-10 Batch 1:  Loss:     0.6774, Validation Accuracy: 0.475600
# Epoch 62, CIFAR-10 Batch 1:  Loss:     0.6377, Validation Accuracy: 0.477200
# Epoch 63, CIFAR-10 Batch 1:  Loss:     0.6325, Validation Accuracy: 0.476000
# Epoch 64, CIFAR-10 Batch 1:  Loss:     0.5889, Validation Accuracy: 0.484600
# Epoch 65, CIFAR-10 Batch 1:  Loss:     0.5744, Validation Accuracy: 0.485400
# Epoch 66, CIFAR-10 Batch 1:  Loss:     0.5540, Validation Accuracy: 0.479600
# Epoch 67, CIFAR-10 Batch 1:  Loss:     0.5311, Validation Accuracy: 0.484800
# Epoch 68, CIFAR-10 Batch 1:  Loss:     0.5231, Validation Accuracy: 0.479400
# Epoch 69, CIFAR-10 Batch 1:  Loss:     0.4985, Validation Accuracy: 0.486200
# Epoch 70, CIFAR-10 Batch 1:  Loss:     0.5038, Validation Accuracy: 0.478600
# Epoch 71, CIFAR-10 Batch 1:  Loss:     0.6864, Validation Accuracy: 0.423600
# Epoch 72, CIFAR-10 Batch 1:  Loss:     0.6929, Validation Accuracy: 0.433400
# Epoch 73, CIFAR-10 Batch 1:  Loss:     0.6471, Validation Accuracy: 0.450600
# Epoch 74, CIFAR-10 Batch 1:  Loss:     0.6012, Validation Accuracy: 0.468000
# Epoch 75, CIFAR-10 Batch 1:  Loss:     0.5226, Validation Accuracy: 0.482800
# Epoch 76, CIFAR-10 Batch 1:  Loss:     0.5151, Validation Accuracy: 0.484000
# Epoch 77, CIFAR-10 Batch 1:  Loss:     0.4766, Validation Accuracy: 0.486800
# Epoch 78, CIFAR-10 Batch 1:  Loss:     0.4630, Validation Accuracy: 0.491200
# Epoch 79, CIFAR-10 Batch 1:  Loss:     0.4248, Validation Accuracy: 0.497000
# Epoch 80, CIFAR-10 Batch 1:  Loss:     0.3956, Validation Accuracy: 0.493000
# Epoch 81, CIFAR-10 Batch 1:  Loss:     0.4018, Validation Accuracy: 0.495000
# Epoch 82, CIFAR-10 Batch 1:  Loss:     0.3779, Validation Accuracy: 0.486000
# Epoch 83, CIFAR-10 Batch 1:  Loss:     0.3615, Validation Accuracy: 0.496000
# Epoch 84, CIFAR-10 Batch 1:  Loss:     0.3523, Validation Accuracy: 0.493000
# Epoch 85, CIFAR-10 Batch 1:  Loss:     0.3437, Validation Accuracy: 0.491600
# Epoch 86, CIFAR-10 Batch 1:  Loss:     0.3113, Validation Accuracy: 0.500800
# Epoch 87, CIFAR-10 Batch 1:  Loss:     0.3154, Validation Accuracy: 0.490800
# Epoch 88, CIFAR-10 Batch 1:  Loss:     0.3111, Validation Accuracy: 0.485800
# Epoch 89, CIFAR-10 Batch 1:  Loss:     0.2942, Validation Accuracy: 0.495200
# Epoch 90, CIFAR-10 Batch 1:  Loss:     0.3131, Validation Accuracy: 0.488000
# Epoch 91, CIFAR-10 Batch 1:  Loss:     0.3140, Validation Accuracy: 0.469600
# Epoch 92, CIFAR-10 Batch 1:  Loss:     0.3091, Validation Accuracy: 0.481400
# Epoch 93, CIFAR-10 Batch 1:  Loss:     0.3191, Validation Accuracy: 0.477000
# Epoch 94, CIFAR-10 Batch 1:  Loss:     0.3823, Validation Accuracy: 0.459600
# Epoch 95, CIFAR-10 Batch 1:  Loss:     0.2665, Validation Accuracy: 0.497800
# Epoch 96, CIFAR-10 Batch 1:  Loss:     0.2693, Validation Accuracy: 0.490400
# Epoch 97, CIFAR-10 Batch 1:  Loss:     0.3028, Validation Accuracy: 0.481600
# Epoch 98, CIFAR-10 Batch 1:  Loss:     0.2741, Validation Accuracy: 0.494600
# Epoch 99, CIFAR-10 Batch 1:  Loss:     0.2632, Validation Accuracy: 0.481800
# Epoch 100, CIFAR-10 Batch 1:  Loss:     0.2585, Validation Accuracy: 0.489400
# Epoch 101, CIFAR-10 Batch 1:  Loss:     0.2400, Validation Accuracy: 0.489800
# Epoch 102, CIFAR-10 Batch 1:  Loss:     0.2370, Validation Accuracy: 0.496200
# Epoch 103, CIFAR-10 Batch 1:  Loss:     0.2717, Validation Accuracy: 0.484800
# Epoch 104, CIFAR-10 Batch 1:  Loss:     0.2196, Validation Accuracy: 0.487000
# Epoch 105, CIFAR-10 Batch 1:  Loss:     0.2887, Validation Accuracy: 0.470000
# Epoch 106, CIFAR-10 Batch 1:  Loss:     0.3388, Validation Accuracy: 0.474400
# Epoch 107, CIFAR-10 Batch 1:  Loss:     0.2970, Validation Accuracy: 0.465400
# Epoch 108, CIFAR-10 Batch 1:  Loss:     0.2504, Validation Accuracy: 0.489600
# Epoch 109, CIFAR-10 Batch 1:  Loss:     0.2275, Validation Accuracy: 0.490600
# Epoch 110, CIFAR-10 Batch 1:  Loss:     0.1956, Validation Accuracy: 0.505200
# Epoch 111, CIFAR-10 Batch 1:  Loss:     0.1943, Validation Accuracy: 0.491400
# Epoch 112, CIFAR-10 Batch 1:  Loss:     0.1766, Validation Accuracy: 0.502800
# Epoch 113, CIFAR-10 Batch 1:  Loss:     0.1740, Validation Accuracy: 0.497400
# Epoch 114, CIFAR-10 Batch 1:  Loss:     0.1554, Validation Accuracy: 0.505600
# Epoch 115, CIFAR-10 Batch 1:  Loss:     0.1523, Validation Accuracy: 0.503800
# Epoch 116, CIFAR-10 Batch 1:  Loss:     0.1341, Validation Accuracy: 0.501000
# Epoch 117, CIFAR-10 Batch 1:  Loss:     0.1235, Validation Accuracy: 0.505600
# Epoch 118, CIFAR-10 Batch 1:  Loss:     0.1107, Validation Accuracy: 0.503400
# Epoch 119, CIFAR-10 Batch 1:  Loss:     0.1081, Validation Accuracy: 0.508000
# Epoch 120, CIFAR-10 Batch 1:  Loss:     0.1026, Validation Accuracy: 0.500800
# Epoch 121, CIFAR-10 Batch 1:  Loss:     0.0969, Validation Accuracy: 0.501000
# Epoch 122, CIFAR-10 Batch 1:  Loss:     0.0952, Validation Accuracy: 0.504200
# Epoch 123, CIFAR-10 Batch 1:  Loss:     0.1023, Validation Accuracy: 0.493800
# Epoch 124, CIFAR-10 Batch 1:  Loss:     0.0946, Validation Accuracy: 0.501600
# Epoch 125, CIFAR-10 Batch 1:  Loss:     0.1213, Validation Accuracy: 0.484200
# Epoch 126, CIFAR-10 Batch 1:  Loss:     0.1458, Validation Accuracy: 0.483800
# Epoch 127, CIFAR-10 Batch 1:  Loss:     0.0911, Validation Accuracy: 0.504200
# Epoch 128, CIFAR-10 Batch 1:  Loss:     0.0768, Validation Accuracy: 0.507200
# Epoch 129, CIFAR-10 Batch 1:  Loss:     0.1145, Validation Accuracy: 0.486600
# Epoch 130, CIFAR-10 Batch 1:  Loss:     0.1350, Validation Accuracy: 0.474200
# Epoch 131, CIFAR-10 Batch 1:  Loss:     0.2951, Validation Accuracy: 0.453200
# Epoch 132, CIFAR-10 Batch 1:  Loss:     0.2511, Validation Accuracy: 0.466800
# Epoch 133, CIFAR-10 Batch 1:  Loss:     0.2539, Validation Accuracy: 0.462800
# Epoch 134, CIFAR-10 Batch 1:  Loss:     0.2205, Validation Accuracy: 0.480800
# Epoch 135, CIFAR-10 Batch 1:  Loss:     0.1952, Validation Accuracy: 0.477000
# Epoch 136, CIFAR-10 Batch 1:  Loss:     0.1528, Validation Accuracy: 0.494400
# Epoch 137, CIFAR-10 Batch 1:  Loss:     0.1234, Validation Accuracy: 0.506200
# Epoch 138, CIFAR-10 Batch 1:  Loss:     0.1140, Validation Accuracy: 0.494200
# Epoch 139, CIFAR-10 Batch 1:  Loss:     0.1042, Validation Accuracy: 0.499600
# Epoch 140, CIFAR-10 Batch 1:  Loss:     0.0878, Validation Accuracy: 0.501600
# Epoch 141, CIFAR-10 Batch 1:  Loss:     0.0878, Validation Accuracy: 0.500200
# Epoch 142, CIFAR-10 Batch 1:  Loss:     0.0740, Validation Accuracy: 0.500400
# Epoch 143, CIFAR-10 Batch 1:  Loss:     0.0860, Validation Accuracy: 0.480600
# Epoch 144, CIFAR-10 Batch 1:  Loss:     0.0860, Validation Accuracy: 0.480400
# Epoch 145, CIFAR-10 Batch 1:  Loss:     0.1225, Validation Accuracy: 0.476200
# Epoch 146, CIFAR-10 Batch 1:  Loss:     0.1461, Validation Accuracy: 0.470000
# Epoch 147, CIFAR-10 Batch 1:  Loss:     0.2007, Validation Accuracy: 0.454800
# Epoch 148, CIFAR-10 Batch 1:  Loss:     0.1472, Validation Accuracy: 0.465600
# Epoch 149, CIFAR-10 Batch 1:  Loss:     0.1497, Validation Accuracy: 0.484800
# Epoch 150, CIFAR-10 Batch 1:  Loss:     0.1057, Validation Accuracy: 0.477800
# Epoch 151, CIFAR-10 Batch 1:  Loss:     0.0956, Validation Accuracy: 0.487400
# Epoch 152, CIFAR-10 Batch 1:  Loss:     0.0813, Validation Accuracy: 0.491200
# Epoch 153, CIFAR-10 Batch 1:  Loss:     0.1087, Validation Accuracy: 0.492600
# Epoch 154, CIFAR-10 Batch 1:  Loss:     0.0678, Validation Accuracy: 0.493600
# Epoch 155, CIFAR-10 Batch 1:  Loss:     0.0667, Validation Accuracy: 0.496400
# Epoch 156, CIFAR-10 Batch 1:  Loss:     0.0681, Validation Accuracy: 0.488400
# Epoch 157, CIFAR-10 Batch 1:  Loss:     0.0562, Validation Accuracy: 0.502600
# Epoch 158, CIFAR-10 Batch 1:  Loss:     0.0510, Validation Accuracy: 0.486600
# Epoch 159, CIFAR-10 Batch 1:  Loss:     0.0906, Validation Accuracy: 0.492400
# Epoch 160, CIFAR-10 Batch 1:  Loss:     0.0668, Validation Accuracy: 0.464800
# Epoch 161, CIFAR-10 Batch 1:  Loss:     0.1319, Validation Accuracy: 0.478600
# Epoch 162, CIFAR-10 Batch 1:  Loss:     0.2213, Validation Accuracy: 0.424600
# Epoch 163, CIFAR-10 Batch 1:  Loss:     0.3980, Validation Accuracy: 0.445800
# Epoch 164, CIFAR-10 Batch 1:  Loss:     0.3560, Validation Accuracy: 0.430800
# Epoch 165, CIFAR-10 Batch 1:  Loss:     0.1328, Validation Accuracy: 0.491600
# Epoch 166, CIFAR-10 Batch 1:  Loss:     0.1616, Validation Accuracy: 0.472800
# Epoch 167, CIFAR-10 Batch 1:  Loss:     0.1019, Validation Accuracy: 0.491600
# Epoch 168, CIFAR-10 Batch 1:  Loss:     0.0722, Validation Accuracy: 0.499600
# Epoch 169, CIFAR-10 Batch 1:  Loss:     0.0613, Validation Accuracy: 0.512600
# Epoch 170, CIFAR-10 Batch 1:  Loss:     0.0536, Validation Accuracy: 0.500200
# Epoch 171, CIFAR-10 Batch 1:  Loss:     0.0489, Validation Accuracy: 0.511000
# Epoch 172, CIFAR-10 Batch 1:  Loss:     0.0529, Validation Accuracy: 0.499800
# Epoch 173, CIFAR-10 Batch 1:  Loss:     0.0527, Validation Accuracy: 0.501200
# Epoch 174, CIFAR-10 Batch 1:  Loss:     0.0601, Validation Accuracy: 0.483000
# Epoch 175, CIFAR-10 Batch 1:  Loss:     0.0363, Validation Accuracy: 0.504800
# Epoch 176, CIFAR-10 Batch 1:  Loss:     0.0284, Validation Accuracy: 0.492800
# Epoch 177, CIFAR-10 Batch 1:  Loss:     0.0224, Validation Accuracy: 0.512000
# Epoch 178, CIFAR-10 Batch 1:  Loss:     0.0192, Validation Accuracy: 0.507600
# Epoch 179, CIFAR-10 Batch 1:  Loss:     0.0187, Validation Accuracy: 0.507400
# Epoch 180, CIFAR-10 Batch 1:  Loss:     0.0167, Validation Accuracy: 0.514400
# Epoch 181, CIFAR-10 Batch 1:  Loss:     0.0134, Validation Accuracy: 0.506800
# Epoch 182, CIFAR-10 Batch 1:  Loss:     0.0129, Validation Accuracy: 0.512400
# Epoch 183, CIFAR-10 Batch 1:  Loss:     0.0143, Validation Accuracy: 0.503600
# Epoch 184, CIFAR-10 Batch 1:  Loss:     0.0121, Validation Accuracy: 0.508600
# Epoch 185, CIFAR-10 Batch 1:  Loss:     0.0124, Validation Accuracy: 0.504400
# Epoch 186, CIFAR-10 Batch 1:  Loss:     0.0101, Validation Accuracy: 0.511000
# Epoch 187, CIFAR-10 Batch 1:  Loss:     0.0097, Validation Accuracy: 0.505800
# Epoch 188, CIFAR-10 Batch 1:  Loss:     0.0086, Validation Accuracy: 0.513800
# Epoch 189, CIFAR-10 Batch 1:  Loss:     0.0075, Validation Accuracy: 0.506200
# Epoch 190, CIFAR-10 Batch 1:  Loss:     0.0086, Validation Accuracy: 0.509800
# Epoch 191, CIFAR-10 Batch 1:  Loss:     0.0097, Validation Accuracy: 0.504000
# Epoch 192, CIFAR-10 Batch 1:  Loss:     0.0128, Validation Accuracy: 0.503600
# Epoch 193, CIFAR-10 Batch 1:  Loss:     0.0207, Validation Accuracy: 0.485400
# Epoch 194, CIFAR-10 Batch 1:  Loss:     0.0183, Validation Accuracy: 0.499400
# Epoch 195, CIFAR-10 Batch 1:  Loss:     0.0194, Validation Accuracy: 0.488800
# Epoch 196, CIFAR-10 Batch 1:  Loss:     0.0166, Validation Accuracy: 0.503600
# Epoch 197, CIFAR-10 Batch 1:  Loss:     0.0110, Validation Accuracy: 0.497600
# Epoch 198, CIFAR-10 Batch 1:  Loss:     0.0094, Validation Accuracy: 0.506400
# Epoch 199, CIFAR-10 Batch 1:  Loss:     0.0098, Validation Accuracy: 0.499800
# Epoch 200, CIFAR-10 Batch 1:  Loss:     0.0093, Validation Accuracy: 0.495400

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Loss:     2.4145, Validation Accuracy: 0.130600
# Epoch  1, CIFAR-10 Batch 2:  Loss:     2.2936, Validation Accuracy: 0.139400
# Epoch  1, CIFAR-10 Batch 3:  Loss:     2.2839, Validation Accuracy: 0.134000
# Epoch  1, CIFAR-10 Batch 4:  Loss:     2.2874, Validation Accuracy: 0.149400
# Epoch  1, CIFAR-10 Batch 5:  Loss:     2.2919, Validation Accuracy: 0.153000
# Epoch  2, CIFAR-10 Batch 1:  Loss:     2.2897, Validation Accuracy: 0.170400
# Epoch  2, CIFAR-10 Batch 2:  Loss:     2.2913, Validation Accuracy: 0.170800
# Epoch  2, CIFAR-10 Batch 3:  Loss:     2.2845, Validation Accuracy: 0.181600
# Epoch  2, CIFAR-10 Batch 4:  Loss:     2.2736, Validation Accuracy: 0.180600
# Epoch  2, CIFAR-10 Batch 5:  Loss:     2.2576, Validation Accuracy: 0.183200
# Epoch  3, CIFAR-10 Batch 1:  Loss:     2.2324, Validation Accuracy: 0.191200
# Epoch  3, CIFAR-10 Batch 2:  Loss:     2.2112, Validation Accuracy: 0.214400
# Epoch  3, CIFAR-10 Batch 3:  Loss:     2.1599, Validation Accuracy: 0.216400
# Epoch  3, CIFAR-10 Batch 4:  Loss:     2.1114, Validation Accuracy: 0.229600
# Epoch  3, CIFAR-10 Batch 5:  Loss:     2.0770, Validation Accuracy: 0.235000
# Epoch  4, CIFAR-10 Batch 1:  Loss:     2.0260, Validation Accuracy: 0.246600
# Epoch  4, CIFAR-10 Batch 2:  Loss:     1.9850, Validation Accuracy: 0.248000
# Epoch  4, CIFAR-10 Batch 3:  Loss:     1.9113, Validation Accuracy: 0.265400
# Epoch  4, CIFAR-10 Batch 4:  Loss:     1.8752, Validation Accuracy: 0.271600
# Epoch  4, CIFAR-10 Batch 5:  Loss:     1.8821, Validation Accuracy: 0.289800
# Epoch  5, CIFAR-10 Batch 1:  Loss:     1.8613, Validation Accuracy: 0.299800
# Epoch  5, CIFAR-10 Batch 2:  Loss:     1.8215, Validation Accuracy: 0.314600
# Epoch  5, CIFAR-10 Batch 3:  Loss:     1.7748, Validation Accuracy: 0.318200
# Epoch  5, CIFAR-10 Batch 4:  Loss:     1.7736, Validation Accuracy: 0.312600
# Epoch  5, CIFAR-10 Batch 5:  Loss:     1.7772, Validation Accuracy: 0.341200
# Epoch  6, CIFAR-10 Batch 1:  Loss:     1.7443, Validation Accuracy: 0.332200
# Epoch  6, CIFAR-10 Batch 2:  Loss:     1.7511, Validation Accuracy: 0.342800
# Epoch  6, CIFAR-10 Batch 3:  Loss:     1.6777, Validation Accuracy: 0.352200
# Epoch  6, CIFAR-10 Batch 4:  Loss:     1.6569, Validation Accuracy: 0.362400
# Epoch  6, CIFAR-10 Batch 5:  Loss:     1.6907, Validation Accuracy: 0.358600
# Epoch  7, CIFAR-10 Batch 1:  Loss:     1.6735, Validation Accuracy: 0.366800
# Epoch  7, CIFAR-10 Batch 2:  Loss:     1.6804, Validation Accuracy: 0.373400
# Epoch  7, CIFAR-10 Batch 3:  Loss:     1.5994, Validation Accuracy: 0.383400
# Epoch  7, CIFAR-10 Batch 4:  Loss:     1.5950, Validation Accuracy: 0.376200
# Epoch  7, CIFAR-10 Batch 5:  Loss:     1.6205, Validation Accuracy: 0.376000
# Epoch  8, CIFAR-10 Batch 1:  Loss:     1.5870, Validation Accuracy: 0.396600
# Epoch  8, CIFAR-10 Batch 2:  Loss:     1.6155, Validation Accuracy: 0.388200
# Epoch  8, CIFAR-10 Batch 3:  Loss:     1.5258, Validation Accuracy: 0.398600
# Epoch  8, CIFAR-10 Batch 4:  Loss:     1.5296, Validation Accuracy: 0.415000
# Epoch  8, CIFAR-10 Batch 5:  Loss:     1.5658, Validation Accuracy: 0.404400
# Epoch  9, CIFAR-10 Batch 1:  Loss:     1.5256, Validation Accuracy: 0.416200
# Epoch  9, CIFAR-10 Batch 2:  Loss:     1.5680, Validation Accuracy: 0.405600
# Epoch  9, CIFAR-10 Batch 3:  Loss:     1.4914, Validation Accuracy: 0.405200
# Epoch  9, CIFAR-10 Batch 4:  Loss:     1.5035, Validation Accuracy: 0.419000
# Epoch  9, CIFAR-10 Batch 5:  Loss:     1.4890, Validation Accuracy: 0.426400
# Epoch 10, CIFAR-10 Batch 1:  Loss:     1.4802, Validation Accuracy: 0.439600
# Epoch 10, CIFAR-10 Batch 2:  Loss:     1.5056, Validation Accuracy: 0.415800
# Epoch 10, CIFAR-10 Batch 3:  Loss:     1.4080, Validation Accuracy: 0.448600
# Epoch 10, CIFAR-10 Batch 4:  Loss:     1.4468, Validation Accuracy: 0.435000
# Epoch 10, CIFAR-10 Batch 5:  Loss:     1.4196, Validation Accuracy: 0.444000
# Epoch 11, CIFAR-10 Batch 1:  Loss:     1.4133, Validation Accuracy: 0.452600
# Epoch 11, CIFAR-10 Batch 2:  Loss:     1.4363, Validation Accuracy: 0.446200
# Epoch 11, CIFAR-10 Batch 3:  Loss:     1.3467, Validation Accuracy: 0.462200
# Epoch 11, CIFAR-10 Batch 4:  Loss:     1.3579, Validation Accuracy: 0.460000
# Epoch 11, CIFAR-10 Batch 5:  Loss:     1.3650, Validation Accuracy: 0.465200
# Epoch 12, CIFAR-10 Batch 1:  Loss:     1.3599, Validation Accuracy: 0.469200
# Epoch 12, CIFAR-10 Batch 2:  Loss:     1.3790, Validation Accuracy: 0.463400
# Epoch 12, CIFAR-10 Batch 3:  Loss:     1.2903, Validation Accuracy: 0.480400
# Epoch 12, CIFAR-10 Batch 4:  Loss:     1.3052, Validation Accuracy: 0.481200
# Epoch 12, CIFAR-10 Batch 5:  Loss:     1.3211, Validation Accuracy: 0.475200
# Epoch 13, CIFAR-10 Batch 1:  Loss:     1.3006, Validation Accuracy: 0.484200
# Epoch 13, CIFAR-10 Batch 2:  Loss:     1.3118, Validation Accuracy: 0.489400
# Epoch 13, CIFAR-10 Batch 3:  Loss:     1.2428, Validation Accuracy: 0.491200
# Epoch 13, CIFAR-10 Batch 4:  Loss:     1.2499, Validation Accuracy: 0.495400
# Epoch 13, CIFAR-10 Batch 5:  Loss:     1.2473, Validation Accuracy: 0.500400
# Epoch 14, CIFAR-10 Batch 1:  Loss:     1.2589, Validation Accuracy: 0.499000
# Epoch 14, CIFAR-10 Batch 2:  Loss:     1.2839, Validation Accuracy: 0.483000
# Epoch 14, CIFAR-10 Batch 3:  Loss:     1.2128, Validation Accuracy: 0.500600
# Epoch 14, CIFAR-10 Batch 4:  Loss:     1.2101, Validation Accuracy: 0.503600
# Epoch 14, CIFAR-10 Batch 5:  Loss:     1.1849, Validation Accuracy: 0.509800
# Epoch 15, CIFAR-10 Batch 1:  Loss:     1.2145, Validation Accuracy: 0.510200
# Epoch 15, CIFAR-10 Batch 2:  Loss:     1.2289, Validation Accuracy: 0.505000
# Epoch 15, CIFAR-10 Batch 3:  Loss:     1.1752, Validation Accuracy: 0.506800
# Epoch 15, CIFAR-10 Batch 4:  Loss:     1.1484, Validation Accuracy: 0.510000
# Epoch 15, CIFAR-10 Batch 5:  Loss:     1.1818, Validation Accuracy: 0.507400
# Epoch 16, CIFAR-10 Batch 1:  Loss:     1.1837, Validation Accuracy: 0.519600
# Epoch 16, CIFAR-10 Batch 2:  Loss:     1.1877, Validation Accuracy: 0.513000
# Epoch 16, CIFAR-10 Batch 3:  Loss:     1.1221, Validation Accuracy: 0.507600
# Epoch 16, CIFAR-10 Batch 4:  Loss:     1.1170, Validation Accuracy: 0.521200
# Epoch 16, CIFAR-10 Batch 5:  Loss:     1.1162, Validation Accuracy: 0.527800
# Epoch 17, CIFAR-10 Batch 1:  Loss:     1.1387, Validation Accuracy: 0.523400
# Epoch 17, CIFAR-10 Batch 2:  Loss:     1.1482, Validation Accuracy: 0.518800
# Epoch 17, CIFAR-10 Batch 3:  Loss:     1.0895, Validation Accuracy: 0.523200
# Epoch 17, CIFAR-10 Batch 4:  Loss:     1.0883, Validation Accuracy: 0.528200
# Epoch 17, CIFAR-10 Batch 5:  Loss:     1.1015, Validation Accuracy: 0.526600
# Epoch 18, CIFAR-10 Batch 1:  Loss:     1.0870, Validation Accuracy: 0.530800
# Epoch 18, CIFAR-10 Batch 2:  Loss:     1.1164, Validation Accuracy: 0.510600
# Epoch 18, CIFAR-10 Batch 3:  Loss:     1.0477, Validation Accuracy: 0.527600
# Epoch 18, CIFAR-10 Batch 4:  Loss:     1.0528, Validation Accuracy: 0.530800
# Epoch 18, CIFAR-10 Batch 5:  Loss:     1.0797, Validation Accuracy: 0.526000
# Epoch 19, CIFAR-10 Batch 1:  Loss:     1.0594, Validation Accuracy: 0.529400
# Epoch 19, CIFAR-10 Batch 2:  Loss:     1.0399, Validation Accuracy: 0.541200
# Epoch 19, CIFAR-10 Batch 3:  Loss:     0.9952, Validation Accuracy: 0.545800
# Epoch 19, CIFAR-10 Batch 4:  Loss:     0.9889, Validation Accuracy: 0.547600
# Epoch 19, CIFAR-10 Batch 5:  Loss:     1.0099, Validation Accuracy: 0.545800
# Epoch 20, CIFAR-10 Batch 1:  Loss:     1.0256, Validation Accuracy: 0.550800
# Epoch 20, CIFAR-10 Batch 2:  Loss:     1.0021, Validation Accuracy: 0.550200
# Epoch 20, CIFAR-10 Batch 3:  Loss:     0.9538, Validation Accuracy: 0.540400
# Epoch 20, CIFAR-10 Batch 4:  Loss:     0.9598, Validation Accuracy: 0.550600
# Epoch 20, CIFAR-10 Batch 5:  Loss:     1.0152, Validation Accuracy: 0.539400
# Epoch 21, CIFAR-10 Batch 1:  Loss:     0.9942, Validation Accuracy: 0.548000
# Epoch 21, CIFAR-10 Batch 2:  Loss:     1.0013, Validation Accuracy: 0.534200
# Epoch 21, CIFAR-10 Batch 3:  Loss:     0.9465, Validation Accuracy: 0.552800
# Epoch 21, CIFAR-10 Batch 4:  Loss:     0.9446, Validation Accuracy: 0.551200
# Epoch 21, CIFAR-10 Batch 5:  Loss:     0.9501, Validation Accuracy: 0.552600
# Epoch 22, CIFAR-10 Batch 1:  Loss:     0.9620, Validation Accuracy: 0.561800
# Epoch 22, CIFAR-10 Batch 2:  Loss:     0.9852, Validation Accuracy: 0.539200
# Epoch 22, CIFAR-10 Batch 3:  Loss:     0.9086, Validation Accuracy: 0.553800
# Epoch 22, CIFAR-10 Batch 4:  Loss:     0.9326, Validation Accuracy: 0.557200
# Epoch 22, CIFAR-10 Batch 5:  Loss:     0.9608, Validation Accuracy: 0.539600
# Epoch 23, CIFAR-10 Batch 1:  Loss:     0.9314, Validation Accuracy: 0.557200
# Epoch 23, CIFAR-10 Batch 2:  Loss:     0.9198, Validation Accuracy: 0.550400
# Epoch 23, CIFAR-10 Batch 3:  Loss:     0.8840, Validation Accuracy: 0.562200
# Epoch 23, CIFAR-10 Batch 4:  Loss:     0.9295, Validation Accuracy: 0.547800
# Epoch 23, CIFAR-10 Batch 5:  Loss:     0.9161, Validation Accuracy: 0.547200
# Epoch 24, CIFAR-10 Batch 1:  Loss:     0.9283, Validation Accuracy: 0.560800
# Epoch 24, CIFAR-10 Batch 2:  Loss:     0.8903, Validation Accuracy: 0.565200
# Epoch 24, CIFAR-10 Batch 3:  Loss:     0.8533, Validation Accuracy: 0.563400
# Epoch 24, CIFAR-10 Batch 4:  Loss:     0.8545, Validation Accuracy: 0.552800
# Epoch 24, CIFAR-10 Batch 5:  Loss:     0.8607, Validation Accuracy: 0.557000
# Epoch 25, CIFAR-10 Batch 1:  Loss:     0.9039, Validation Accuracy: 0.557600
# Epoch 25, CIFAR-10 Batch 2:  Loss:     0.8675, Validation Accuracy: 0.565400
# Epoch 25, CIFAR-10 Batch 3:  Loss:     0.8106, Validation Accuracy: 0.570800
# Epoch 25, CIFAR-10 Batch 4:  Loss:     0.8161, Validation Accuracy: 0.565400
# Epoch 25, CIFAR-10 Batch 5:  Loss:     0.8331, Validation Accuracy: 0.563000
# Epoch 26, CIFAR-10 Batch 1:  Loss:     0.8701, Validation Accuracy: 0.552800
# Epoch 26, CIFAR-10 Batch 2:  Loss:     0.8574, Validation Accuracy: 0.562000
# Epoch 26, CIFAR-10 Batch 3:  Loss:     0.7932, Validation Accuracy: 0.563600
# Epoch 26, CIFAR-10 Batch 4:  Loss:     0.7899, Validation Accuracy: 0.567000
# Epoch 26, CIFAR-10 Batch 5:  Loss:     0.7898, Validation Accuracy: 0.574000
# Epoch 27, CIFAR-10 Batch 1:  Loss:     0.8254, Validation Accuracy: 0.579000
# Epoch 27, CIFAR-10 Batch 2:  Loss:     0.8017, Validation Accuracy: 0.570600
# Epoch 27, CIFAR-10 Batch 3:  Loss:     0.7916, Validation Accuracy: 0.555400
# Epoch 27, CIFAR-10 Batch 4:  Loss:     0.8349, Validation Accuracy: 0.539000
# Epoch 27, CIFAR-10 Batch 5:  Loss:     0.8200, Validation Accuracy: 0.558000
# Epoch 28, CIFAR-10 Batch 1:  Loss:     0.8343, Validation Accuracy: 0.568600
# Epoch 28, CIFAR-10 Batch 2:  Loss:     0.7992, Validation Accuracy: 0.582200
# Epoch 28, CIFAR-10 Batch 3:  Loss:     0.7341, Validation Accuracy: 0.579800
# Epoch 28, CIFAR-10 Batch 4:  Loss:     0.7335, Validation Accuracy: 0.568800
# Epoch 28, CIFAR-10 Batch 5:  Loss:     0.7502, Validation Accuracy: 0.573800
# Epoch 29, CIFAR-10 Batch 1:  Loss:     0.7751, Validation Accuracy: 0.580800
# Epoch 29, CIFAR-10 Batch 2:  Loss:     0.7611, Validation Accuracy: 0.580000
# Epoch 29, CIFAR-10 Batch 3:  Loss:     0.7066, Validation Accuracy: 0.583600
# Epoch 29, CIFAR-10 Batch 4:  Loss:     0.7234, Validation Accuracy: 0.561600
# Epoch 29, CIFAR-10 Batch 5:  Loss:     0.7192, Validation Accuracy: 0.585200
# Epoch 30, CIFAR-10 Batch 1:  Loss:     0.7333, Validation Accuracy: 0.593600
# Epoch 30, CIFAR-10 Batch 2:  Loss:     0.7241, Validation Accuracy: 0.586400
# Epoch 30, CIFAR-10 Batch 3:  Loss:     0.6841, Validation Accuracy: 0.581000
# Epoch 30, CIFAR-10 Batch 4:  Loss:     0.7163, Validation Accuracy: 0.578200
# Epoch 30, CIFAR-10 Batch 5:  Loss:     0.7095, Validation Accuracy: 0.587400
# Epoch 31, CIFAR-10 Batch 1:  Loss:     0.7261, Validation Accuracy: 0.587400
# Epoch 31, CIFAR-10 Batch 2:  Loss:     0.7046, Validation Accuracy: 0.584000
# Epoch 31, CIFAR-10 Batch 3:  Loss:     0.6653, Validation Accuracy: 0.591000
# Epoch 31, CIFAR-10 Batch 4:  Loss:     0.7475, Validation Accuracy: 0.569400
# Epoch 31, CIFAR-10 Batch 5:  Loss:     0.7369, Validation Accuracy: 0.573400
# Epoch 32, CIFAR-10 Batch 1:  Loss:     0.7467, Validation Accuracy: 0.583200
# Epoch 32, CIFAR-10 Batch 2:  Loss:     0.7335, Validation Accuracy: 0.577800
# Epoch 32, CIFAR-10 Batch 3:  Loss:     0.6605, Validation Accuracy: 0.594600
# Epoch 32, CIFAR-10 Batch 4:  Loss:     0.6473, Validation Accuracy: 0.588800
# Epoch 32, CIFAR-10 Batch 5:  Loss:     0.6457, Validation Accuracy: 0.586200
# Epoch 33, CIFAR-10 Batch 1:  Loss:     0.6995, Validation Accuracy: 0.584200
# Epoch 33, CIFAR-10 Batch 2:  Loss:     0.6676, Validation Accuracy: 0.586400
# Epoch 33, CIFAR-10 Batch 3:  Loss:     0.6187, Validation Accuracy: 0.592200
# Epoch 33, CIFAR-10 Batch 4:  Loss:     0.6222, Validation Accuracy: 0.588400
# Epoch 33, CIFAR-10 Batch 5:  Loss:     0.6252, Validation Accuracy: 0.593600
# Epoch 34, CIFAR-10 Batch 1:  Loss:     0.6832, Validation Accuracy: 0.586400
# Epoch 34, CIFAR-10 Batch 2:  Loss:     0.6582, Validation Accuracy: 0.588000
# Epoch 34, CIFAR-10 Batch 3:  Loss:     0.5890, Validation Accuracy: 0.597400
# Epoch 34, CIFAR-10 Batch 4:  Loss:     0.6696, Validation Accuracy: 0.573800
# Epoch 34, CIFAR-10 Batch 5:  Loss:     0.6251, Validation Accuracy: 0.588800
# Epoch 35, CIFAR-10 Batch 1:  Loss:     0.6914, Validation Accuracy: 0.577600
# Epoch 35, CIFAR-10 Batch 2:  Loss:     0.6441, Validation Accuracy: 0.596200
# Epoch 35, CIFAR-10 Batch 3:  Loss:     0.5986, Validation Accuracy: 0.599000
# Epoch 35, CIFAR-10 Batch 4:  Loss:     0.6064, Validation Accuracy: 0.591800
# Epoch 35, CIFAR-10 Batch 5:  Loss:     0.6207, Validation Accuracy: 0.580400
# Epoch 36, CIFAR-10 Batch 1:  Loss:     0.6694, Validation Accuracy: 0.592400
# Epoch 36, CIFAR-10 Batch 2:  Loss:     0.6445, Validation Accuracy: 0.589000
# Epoch 36, CIFAR-10 Batch 3:  Loss:     0.5801, Validation Accuracy: 0.595200
# Epoch 36, CIFAR-10 Batch 4:  Loss:     0.6144, Validation Accuracy: 0.589600
# Epoch 36, CIFAR-10 Batch 5:  Loss:     0.5956, Validation Accuracy: 0.593800
# Epoch 37, CIFAR-10 Batch 1:  Loss:     0.6224, Validation Accuracy: 0.600800
# Epoch 37, CIFAR-10 Batch 2:  Loss:     0.5932, Validation Accuracy: 0.603200
# Epoch 37, CIFAR-10 Batch 3:  Loss:     0.5607, Validation Accuracy: 0.593400
# Epoch 37, CIFAR-10 Batch 4:  Loss:     0.6061, Validation Accuracy: 0.582800
# Epoch 37, CIFAR-10 Batch 5:  Loss:     0.5954, Validation Accuracy: 0.579400
# Epoch 38, CIFAR-10 Batch 1:  Loss:     0.6020, Validation Accuracy: 0.600800
# Epoch 38, CIFAR-10 Batch 2:  Loss:     0.5761, Validation Accuracy: 0.607400
# Epoch 38, CIFAR-10 Batch 3:  Loss:     0.5356, Validation Accuracy: 0.600800
# Epoch 38, CIFAR-10 Batch 4:  Loss:     0.5410, Validation Accuracy: 0.599000
# Epoch 38, CIFAR-10 Batch 5:  Loss:     0.5525, Validation Accuracy: 0.591800
# Epoch 39, CIFAR-10 Batch 1:  Loss:     0.5775, Validation Accuracy: 0.607800
# Epoch 39, CIFAR-10 Batch 2:  Loss:     0.5742, Validation Accuracy: 0.608000
# Epoch 39, CIFAR-10 Batch 3:  Loss:     0.5256, Validation Accuracy: 0.599400
# Epoch 39, CIFAR-10 Batch 4:  Loss:     0.5133, Validation Accuracy: 0.609200
# Epoch 39, CIFAR-10 Batch 5:  Loss:     0.5223, Validation Accuracy: 0.594600
# Epoch 40, CIFAR-10 Batch 1:  Loss:     0.5534, Validation Accuracy: 0.606600
# Epoch 40, CIFAR-10 Batch 2:  Loss:     0.5426, Validation Accuracy: 0.610600
# Epoch 40, CIFAR-10 Batch 3:  Loss:     0.4970, Validation Accuracy: 0.601000
# Epoch 40, CIFAR-10 Batch 4:  Loss:     0.5012, Validation Accuracy: 0.604400
# Epoch 40, CIFAR-10 Batch 5:  Loss:     0.5057, Validation Accuracy: 0.597000
# Epoch 41, CIFAR-10 Batch 1:  Loss:     0.5391, Validation Accuracy: 0.611400
# Epoch 41, CIFAR-10 Batch 2:  Loss:     0.4881, Validation Accuracy: 0.607000
# Epoch 41, CIFAR-10 Batch 3:  Loss:     0.4811, Validation Accuracy: 0.598600
# Epoch 41, CIFAR-10 Batch 4:  Loss:     0.5268, Validation Accuracy: 0.588000
# Epoch 41, CIFAR-10 Batch 5:  Loss:     0.5119, Validation Accuracy: 0.587200
# Epoch 42, CIFAR-10 Batch 1:  Loss:     0.5362, Validation Accuracy: 0.604800
# Epoch 42, CIFAR-10 Batch 2:  Loss:     0.4755, Validation Accuracy: 0.608000
# Epoch 42, CIFAR-10 Batch 3:  Loss:     0.4763, Validation Accuracy: 0.603600
# Epoch 42, CIFAR-10 Batch 4:  Loss:     0.4832, Validation Accuracy: 0.598000
# Epoch 42, CIFAR-10 Batch 5:  Loss:     0.5099, Validation Accuracy: 0.595200
# Epoch 43, CIFAR-10 Batch 1:  Loss:     0.5298, Validation Accuracy: 0.611000
# Epoch 43, CIFAR-10 Batch 2:  Loss:     0.5070, Validation Accuracy: 0.596600
# Epoch 43, CIFAR-10 Batch 3:  Loss:     0.4408, Validation Accuracy: 0.608200
# Epoch 43, CIFAR-10 Batch 4:  Loss:     0.5135, Validation Accuracy: 0.599000
# Epoch 43, CIFAR-10 Batch 5:  Loss:     0.4836, Validation Accuracy: 0.598000
# Epoch 44, CIFAR-10 Batch 1:  Loss:     0.5424, Validation Accuracy: 0.600800
# Epoch 44, CIFAR-10 Batch 2:  Loss:     0.4693, Validation Accuracy: 0.603200
# Epoch 44, CIFAR-10 Batch 3:  Loss:     0.4675, Validation Accuracy: 0.601200
# Epoch 44, CIFAR-10 Batch 4:  Loss:     0.5173, Validation Accuracy: 0.587600
# Epoch 44, CIFAR-10 Batch 5:  Loss:     0.5168, Validation Accuracy: 0.606800
# Epoch 45, CIFAR-10 Batch 1:  Loss:     0.5471, Validation Accuracy: 0.615800
# Epoch 45, CIFAR-10 Batch 2:  Loss:     0.5177, Validation Accuracy: 0.594000
# Epoch 45, CIFAR-10 Batch 3:  Loss:     0.4544, Validation Accuracy: 0.614800
# Epoch 45, CIFAR-10 Batch 4:  Loss:     0.5254, Validation Accuracy: 0.588000
# Epoch 45, CIFAR-10 Batch 5:  Loss:     0.4773, Validation Accuracy: 0.619800
# Epoch 46, CIFAR-10 Batch 1:  Loss:     0.5186, Validation Accuracy: 0.619400
# Epoch 46, CIFAR-10 Batch 2:  Loss:     0.4768, Validation Accuracy: 0.599600
# Epoch 46, CIFAR-10 Batch 3:  Loss:     0.4454, Validation Accuracy: 0.610200
# Epoch 46, CIFAR-10 Batch 4:  Loss:     0.4420, Validation Accuracy: 0.607400
# Epoch 46, CIFAR-10 Batch 5:  Loss:     0.4399, Validation Accuracy: 0.612000
# Epoch 47, CIFAR-10 Batch 1:  Loss:     0.4608, Validation Accuracy: 0.615800
# Epoch 47, CIFAR-10 Batch 2:  Loss:     0.4298, Validation Accuracy: 0.603400
# Epoch 47, CIFAR-10 Batch 3:  Loss:     0.4243, Validation Accuracy: 0.609200
# Epoch 47, CIFAR-10 Batch 4:  Loss:     0.4387, Validation Accuracy: 0.600200
# Epoch 47, CIFAR-10 Batch 5:  Loss:     0.4367, Validation Accuracy: 0.614600
# Epoch 48, CIFAR-10 Batch 1:  Loss:     0.4680, Validation Accuracy: 0.610600
# Epoch 48, CIFAR-10 Batch 2:  Loss:     0.4307, Validation Accuracy: 0.618800
# Epoch 48, CIFAR-10 Batch 3:  Loss:     0.3880, Validation Accuracy: 0.624600
# Epoch 48, CIFAR-10 Batch 4:  Loss:     0.4077, Validation Accuracy: 0.613600
# Epoch 48, CIFAR-10 Batch 5:  Loss:     0.3848, Validation Accuracy: 0.621800
# Epoch 49, CIFAR-10 Batch 1:  Loss:     0.4239, Validation Accuracy: 0.615400
# Epoch 49, CIFAR-10 Batch 2:  Loss:     0.4034, Validation Accuracy: 0.615400
# Epoch 49, CIFAR-10 Batch 3:  Loss:     0.3592, Validation Accuracy: 0.618400
# Epoch 49, CIFAR-10 Batch 4:  Loss:     0.3743, Validation Accuracy: 0.618600
# Epoch 49, CIFAR-10 Batch 5:  Loss:     0.3699, Validation Accuracy: 0.620400
# Epoch 50, CIFAR-10 Batch 1:  Loss:     0.4021, Validation Accuracy: 0.618800
# Epoch 50, CIFAR-10 Batch 2:  Loss:     0.3707, Validation Accuracy: 0.618400
# Epoch 50, CIFAR-10 Batch 3:  Loss:     0.3398, Validation Accuracy: 0.619400
# Epoch 50, CIFAR-10 Batch 4:  Loss:     0.3537, Validation Accuracy: 0.614200
# Epoch 50, CIFAR-10 Batch 5:  Loss:     0.3431, Validation Accuracy: 0.619600
# Epoch 51, CIFAR-10 Batch 1:  Loss:     0.3789, Validation Accuracy: 0.624400
# Epoch 51, CIFAR-10 Batch 2:  Loss:     0.3525, Validation Accuracy: 0.616600
# Epoch 51, CIFAR-10 Batch 3:  Loss:     0.3131, Validation Accuracy: 0.620000
# Epoch 51, CIFAR-10 Batch 4:  Loss:     0.3293, Validation Accuracy: 0.623600
# Epoch 51, CIFAR-10 Batch 5:  Loss:     0.3285, Validation Accuracy: 0.617600
# Epoch 52, CIFAR-10 Batch 1:  Loss:     0.3840, Validation Accuracy: 0.621200
# Epoch 52, CIFAR-10 Batch 2:  Loss:     0.3359, Validation Accuracy: 0.621600
# Epoch 52, CIFAR-10 Batch 3:  Loss:     0.3091, Validation Accuracy: 0.621000
# Epoch 52, CIFAR-10 Batch 4:  Loss:     0.3215, Validation Accuracy: 0.611600
# Epoch 52, CIFAR-10 Batch 5:  Loss:     0.3197, Validation Accuracy: 0.619600
# Epoch 53, CIFAR-10 Batch 1:  Loss:     0.3607, Validation Accuracy: 0.623200
# Epoch 53, CIFAR-10 Batch 2:  Loss:     0.3458, Validation Accuracy: 0.611200
# Epoch 53, CIFAR-10 Batch 3:  Loss:     0.3086, Validation Accuracy: 0.618400
# Epoch 53, CIFAR-10 Batch 4:  Loss:     0.3348, Validation Accuracy: 0.607000
# Epoch 53, CIFAR-10 Batch 5:  Loss:     0.3122, Validation Accuracy: 0.622200
# Epoch 54, CIFAR-10 Batch 1:  Loss:     0.3746, Validation Accuracy: 0.625000
# Epoch 54, CIFAR-10 Batch 2:  Loss:     0.3629, Validation Accuracy: 0.607000
# Epoch 54, CIFAR-10 Batch 3:  Loss:     0.3387, Validation Accuracy: 0.607800
# Epoch 54, CIFAR-10 Batch 4:  Loss:     0.3989, Validation Accuracy: 0.582200
# Epoch 54, CIFAR-10 Batch 5:  Loss:     0.3849, Validation Accuracy: 0.595800
# Epoch 55, CIFAR-10 Batch 1:  Loss:     0.4425, Validation Accuracy: 0.589800
# Epoch 55, CIFAR-10 Batch 2:  Loss:     0.3781, Validation Accuracy: 0.620600
# Epoch 55, CIFAR-10 Batch 3:  Loss:     0.3517, Validation Accuracy: 0.617200
# Epoch 55, CIFAR-10 Batch 4:  Loss:     0.3272, Validation Accuracy: 0.619600
# Epoch 55, CIFAR-10 Batch 5:  Loss:     0.3148, Validation Accuracy: 0.616400
# Epoch 56, CIFAR-10 Batch 1:  Loss:     0.3553, Validation Accuracy: 0.618600
# Epoch 56, CIFAR-10 Batch 2:  Loss:     0.3087, Validation Accuracy: 0.631600
# Epoch 56, CIFAR-10 Batch 3:  Loss:     0.3095, Validation Accuracy: 0.614800
# Epoch 56, CIFAR-10 Batch 4:  Loss:     0.2990, Validation Accuracy: 0.619400
# Epoch 56, CIFAR-10 Batch 5:  Loss:     0.2786, Validation Accuracy: 0.624200
# Epoch 57, CIFAR-10 Batch 1:  Loss:     0.3354, Validation Accuracy: 0.615800
# Epoch 57, CIFAR-10 Batch 2:  Loss:     0.2950, Validation Accuracy: 0.627800
# Epoch 57, CIFAR-10 Batch 3:  Loss:     0.2684, Validation Accuracy: 0.625000
# Epoch 57, CIFAR-10 Batch 4:  Loss:     0.2775, Validation Accuracy: 0.621400
# Epoch 57, CIFAR-10 Batch 5:  Loss:     0.2676, Validation Accuracy: 0.622400
# Epoch 58, CIFAR-10 Batch 1:  Loss:     0.2949, Validation Accuracy: 0.623000
# Epoch 58, CIFAR-10 Batch 2:  Loss:     0.2633, Validation Accuracy: 0.631600
# Epoch 58, CIFAR-10 Batch 3:  Loss:     0.2395, Validation Accuracy: 0.631600
# Epoch 58, CIFAR-10 Batch 4:  Loss:     0.2537, Validation Accuracy: 0.617000
# Epoch 58, CIFAR-10 Batch 5:  Loss:     0.2848, Validation Accuracy: 0.607400
# Epoch 59, CIFAR-10 Batch 1:  Loss:     0.3292, Validation Accuracy: 0.618000
# Epoch 59, CIFAR-10 Batch 2:  Loss:     0.2691, Validation Accuracy: 0.627000
# Epoch 59, CIFAR-10 Batch 3:  Loss:     0.2460, Validation Accuracy: 0.628600
# Epoch 59, CIFAR-10 Batch 4:  Loss:     0.2623, Validation Accuracy: 0.627000
# Epoch 59, CIFAR-10 Batch 5:  Loss:     0.2577, Validation Accuracy: 0.620400
# Epoch 60, CIFAR-10 Batch 1:  Loss:     0.2893, Validation Accuracy: 0.629000
# Epoch 60, CIFAR-10 Batch 2:  Loss:     0.2432, Validation Accuracy: 0.627400
# Epoch 60, CIFAR-10 Batch 3:  Loss:     0.2622, Validation Accuracy: 0.609600
# Epoch 60, CIFAR-10 Batch 4:  Loss:     0.2585, Validation Accuracy: 0.612400
# Epoch 60, CIFAR-10 Batch 5:  Loss:     0.2439, Validation Accuracy: 0.621200
# Epoch 61, CIFAR-10 Batch 1:  Loss:     0.3221, Validation Accuracy: 0.618600
# Epoch 61, CIFAR-10 Batch 2:  Loss:     0.2452, Validation Accuracy: 0.631000
# Epoch 61, CIFAR-10 Batch 3:  Loss:     0.2451, Validation Accuracy: 0.616600
# Epoch 61, CIFAR-10 Batch 4:  Loss:     0.2356, Validation Accuracy: 0.622600
# Epoch 61, CIFAR-10 Batch 5:  Loss:     0.2209, Validation Accuracy: 0.633000
# Epoch 62, CIFAR-10 Batch 1:  Loss:     0.2766, Validation Accuracy: 0.623200
# Epoch 62, CIFAR-10 Batch 2:  Loss:     0.2456, Validation Accuracy: 0.611200
# Epoch 62, CIFAR-10 Batch 3:  Loss:     0.2589, Validation Accuracy: 0.612400
# Epoch 62, CIFAR-10 Batch 4:  Loss:     0.2448, Validation Accuracy: 0.620200
# Epoch 62, CIFAR-10 Batch 5:  Loss:     0.2401, Validation Accuracy: 0.616600
# Epoch 63, CIFAR-10 Batch 1:  Loss:     0.2648, Validation Accuracy: 0.624800
# Epoch 63, CIFAR-10 Batch 2:  Loss:     0.2531, Validation Accuracy: 0.621400
# Epoch 63, CIFAR-10 Batch 3:  Loss:     0.2175, Validation Accuracy: 0.630800
# Epoch 63, CIFAR-10 Batch 4:  Loss:     0.2540, Validation Accuracy: 0.614800
# Epoch 63, CIFAR-10 Batch 5:  Loss:     0.2514, Validation Accuracy: 0.605200
# Epoch 64, CIFAR-10 Batch 1:  Loss:     0.2954, Validation Accuracy: 0.595400
# Epoch 64, CIFAR-10 Batch 2:  Loss:     0.2766, Validation Accuracy: 0.619600
# Epoch 64, CIFAR-10 Batch 3:  Loss:     0.2635, Validation Accuracy: 0.613000
# Epoch 64, CIFAR-10 Batch 4:  Loss:     0.2950, Validation Accuracy: 0.608400
# Epoch 64, CIFAR-10 Batch 5:  Loss:     0.2601, Validation Accuracy: 0.620000
# Epoch 65, CIFAR-10 Batch 1:  Loss:     0.3001, Validation Accuracy: 0.615000
# Epoch 65, CIFAR-10 Batch 2:  Loss:     0.2892, Validation Accuracy: 0.620800
# Epoch 65, CIFAR-10 Batch 3:  Loss:     0.2328, Validation Accuracy: 0.617400
# Epoch 65, CIFAR-10 Batch 4:  Loss:     0.2350, Validation Accuracy: 0.624200
# Epoch 65, CIFAR-10 Batch 5:  Loss:     0.2069, Validation Accuracy: 0.630200
# Epoch 66, CIFAR-10 Batch 1:  Loss:     0.2363, Validation Accuracy: 0.628200
# Epoch 66, CIFAR-10 Batch 2:  Loss:     0.2094, Validation Accuracy: 0.627400
# Epoch 66, CIFAR-10 Batch 3:  Loss:     0.1853, Validation Accuracy: 0.620600
# Epoch 66, CIFAR-10 Batch 4:  Loss:     0.2157, Validation Accuracy: 0.625000
# Epoch 66, CIFAR-10 Batch 5:  Loss:     0.1984, Validation Accuracy: 0.628000
# Epoch 67, CIFAR-10 Batch 1:  Loss:     0.2152, Validation Accuracy: 0.628200
# Epoch 67, CIFAR-10 Batch 2:  Loss:     0.2062, Validation Accuracy: 0.625800
# Epoch 67, CIFAR-10 Batch 3:  Loss:     0.1770, Validation Accuracy: 0.624400
# Epoch 67, CIFAR-10 Batch 4:  Loss:     0.1907, Validation Accuracy: 0.636200
# Epoch 67, CIFAR-10 Batch 5:  Loss:     0.1635, Validation Accuracy: 0.639400
# Epoch 68, CIFAR-10 Batch 1:  Loss:     0.1971, Validation Accuracy: 0.628000
# Epoch 68, CIFAR-10 Batch 2:  Loss:     0.1964, Validation Accuracy: 0.631800
# Epoch 68, CIFAR-10 Batch 3:  Loss:     0.1639, Validation Accuracy: 0.620400
# Epoch 68, CIFAR-10 Batch 4:  Loss:     0.1847, Validation Accuracy: 0.629200
# Epoch 68, CIFAR-10 Batch 5:  Loss:     0.1454, Validation Accuracy: 0.639600
# Epoch 69, CIFAR-10 Batch 1:  Loss:     0.1975, Validation Accuracy: 0.623200
# Epoch 69, CIFAR-10 Batch 2:  Loss:     0.1875, Validation Accuracy: 0.623200
# Epoch 69, CIFAR-10 Batch 3:  Loss:     0.1507, Validation Accuracy: 0.627400
# Epoch 69, CIFAR-10 Batch 4:  Loss:     0.1702, Validation Accuracy: 0.635400
# Epoch 69, CIFAR-10 Batch 5:  Loss:     0.1654, Validation Accuracy: 0.621200
# Epoch 70, CIFAR-10 Batch 1:  Loss:     0.1939, Validation Accuracy: 0.620200
# Epoch 70, CIFAR-10 Batch 2:  Loss:     0.1891, Validation Accuracy: 0.628000
# Epoch 70, CIFAR-10 Batch 3:  Loss:     0.1588, Validation Accuracy: 0.618200
# Epoch 70, CIFAR-10 Batch 4:  Loss:     0.1612, Validation Accuracy: 0.634000
# Epoch 70, CIFAR-10 Batch 5:  Loss:     0.1864, Validation Accuracy: 0.615200
# Epoch 71, CIFAR-10 Batch 1:  Loss:     0.2343, Validation Accuracy: 0.620800
# Epoch 71, CIFAR-10 Batch 2:  Loss:     0.1943, Validation Accuracy: 0.616400
# Epoch 71, CIFAR-10 Batch 3:  Loss:     0.2000, Validation Accuracy: 0.615200
# Epoch 71, CIFAR-10 Batch 4:  Loss:     0.1984, Validation Accuracy: 0.611400
# Epoch 71, CIFAR-10 Batch 5:  Loss:     0.2316, Validation Accuracy: 0.613400
# Epoch 72, CIFAR-10 Batch 1:  Loss:     0.2343, Validation Accuracy: 0.627400
# Epoch 72, CIFAR-10 Batch 2:  Loss:     0.2069, Validation Accuracy: 0.619200
# Epoch 72, CIFAR-10 Batch 3:  Loss:     0.1755, Validation Accuracy: 0.622800
# Epoch 72, CIFAR-10 Batch 4:  Loss:     0.1750, Validation Accuracy: 0.618000
# Epoch 72, CIFAR-10 Batch 5:  Loss:     0.1613, Validation Accuracy: 0.626000
# Epoch 73, CIFAR-10 Batch 1:  Loss:     0.1984, Validation Accuracy: 0.619400
# Epoch 73, CIFAR-10 Batch 2:  Loss:     0.1600, Validation Accuracy: 0.634800
# Epoch 73, CIFAR-10 Batch 3:  Loss:     0.1305, Validation Accuracy: 0.632600
# Epoch 73, CIFAR-10 Batch 4:  Loss:     0.1329, Validation Accuracy: 0.633800
# Epoch 73, CIFAR-10 Batch 5:  Loss:     0.1216, Validation Accuracy: 0.629400
# Epoch 74, CIFAR-10 Batch 1:  Loss:     0.1525, Validation Accuracy: 0.637000
# Epoch 74, CIFAR-10 Batch 2:  Loss:     0.1429, Validation Accuracy: 0.633600
# Epoch 74, CIFAR-10 Batch 3:  Loss:     0.1222, Validation Accuracy: 0.624400
# Epoch 74, CIFAR-10 Batch 4:  Loss:     0.1208, Validation Accuracy: 0.630400
# Epoch 74, CIFAR-10 Batch 5:  Loss:     0.1207, Validation Accuracy: 0.633400
# Epoch 75, CIFAR-10 Batch 1:  Loss:     0.1438, Validation Accuracy: 0.632800
# Epoch 75, CIFAR-10 Batch 2:  Loss:     0.1312, Validation Accuracy: 0.635200
# Epoch 75, CIFAR-10 Batch 3:  Loss:     0.1167, Validation Accuracy: 0.625400
# Epoch 75, CIFAR-10 Batch 4:  Loss:     0.1393, Validation Accuracy: 0.632000
# Epoch 75, CIFAR-10 Batch 5:  Loss:     0.1261, Validation Accuracy: 0.625200
# Epoch 76, CIFAR-10 Batch 1:  Loss:     0.1907, Validation Accuracy: 0.617600
# Epoch 76, CIFAR-10 Batch 2:  Loss:     0.1823, Validation Accuracy: 0.615600
# Epoch 76, CIFAR-10 Batch 3:  Loss:     0.1436, Validation Accuracy: 0.620200
# Epoch 76, CIFAR-10 Batch 4:  Loss:     0.1415, Validation Accuracy: 0.621800
# Epoch 76, CIFAR-10 Batch 5:  Loss:     0.1401, Validation Accuracy: 0.627800
# Epoch 77, CIFAR-10 Batch 1:  Loss:     0.1539, Validation Accuracy: 0.626000
# Epoch 77, CIFAR-10 Batch 2:  Loss:     0.1440, Validation Accuracy: 0.635200
# Epoch 77, CIFAR-10 Batch 3:  Loss:     0.1125, Validation Accuracy: 0.622400
# Epoch 77, CIFAR-10 Batch 4:  Loss:     0.1379, Validation Accuracy: 0.624600
# Epoch 77, CIFAR-10 Batch 5:  Loss:     0.1176, Validation Accuracy: 0.630400
# Epoch 78, CIFAR-10 Batch 1:  Loss:     0.1636, Validation Accuracy: 0.619000
# Epoch 78, CIFAR-10 Batch 2:  Loss:     0.1504, Validation Accuracy: 0.629200
# Epoch 78, CIFAR-10 Batch 3:  Loss:     0.1145, Validation Accuracy: 0.627400
# Epoch 78, CIFAR-10 Batch 4:  Loss:     0.1287, Validation Accuracy: 0.628400
# Epoch 78, CIFAR-10 Batch 5:  Loss:     0.1147, Validation Accuracy: 0.627400
# Epoch 79, CIFAR-10 Batch 1:  Loss:     0.1402, Validation Accuracy: 0.628400
# Epoch 79, CIFAR-10 Batch 2:  Loss:     0.1632, Validation Accuracy: 0.628400
# Epoch 79, CIFAR-10 Batch 3:  Loss:     0.1171, Validation Accuracy: 0.613800
# Epoch 79, CIFAR-10 Batch 4:  Loss:     0.1241, Validation Accuracy: 0.624000
# Epoch 79, CIFAR-10 Batch 5:  Loss:     0.1235, Validation Accuracy: 0.619200
# Epoch 80, CIFAR-10 Batch 1:  Loss:     0.1804, Validation Accuracy: 0.615800
# Epoch 80, CIFAR-10 Batch 2:  Loss:     0.1486, Validation Accuracy: 0.627200
# Epoch 80, CIFAR-10 Batch 3:  Loss:     0.1470, Validation Accuracy: 0.608800
# Epoch 80, CIFAR-10 Batch 4:  Loss:     0.1643, Validation Accuracy: 0.613400
# Epoch 80, CIFAR-10 Batch 5:  Loss:     0.1368, Validation Accuracy: 0.614200
# Epoch 81, CIFAR-10 Batch 1:  Loss:     0.1633, Validation Accuracy: 0.630600
# Epoch 81, CIFAR-10 Batch 2:  Loss:     0.1587, Validation Accuracy: 0.623400
# Epoch 81, CIFAR-10 Batch 3:  Loss:     0.1335, Validation Accuracy: 0.612000
# Epoch 81, CIFAR-10 Batch 4:  Loss:     0.1711, Validation Accuracy: 0.618400
# Epoch 81, CIFAR-10 Batch 5:  Loss:     0.1527, Validation Accuracy: 0.600800
# Epoch 82, CIFAR-10 Batch 1:  Loss:     0.2014, Validation Accuracy: 0.622600
# Epoch 82, CIFAR-10 Batch 2:  Loss:     0.2020, Validation Accuracy: 0.605000
# Epoch 82, CIFAR-10 Batch 3:  Loss:     0.1612, Validation Accuracy: 0.612200
# Epoch 82, CIFAR-10 Batch 4:  Loss:     0.1622, Validation Accuracy: 0.613400
# Epoch 82, CIFAR-10 Batch 5:  Loss:     0.1762, Validation Accuracy: 0.600200
# Epoch 83, CIFAR-10 Batch 1:  Loss:     0.1503, Validation Accuracy: 0.630200
# Epoch 83, CIFAR-10 Batch 2:  Loss:     0.1780, Validation Accuracy: 0.629400
# Epoch 83, CIFAR-10 Batch 3:  Loss:     0.1447, Validation Accuracy: 0.623200
# Epoch 83, CIFAR-10 Batch 4:  Loss:     0.1557, Validation Accuracy: 0.618400
# Epoch 83, CIFAR-10 Batch 5:  Loss:     0.1762, Validation Accuracy: 0.601400
# Epoch 84, CIFAR-10 Batch 1:  Loss:     0.1964, Validation Accuracy: 0.604000
# Epoch 84, CIFAR-10 Batch 2:  Loss:     0.1744, Validation Accuracy: 0.606400
# Epoch 84, CIFAR-10 Batch 3:  Loss:     0.2452, Validation Accuracy: 0.603600
# Epoch 84, CIFAR-10 Batch 4:  Loss:     0.2101, Validation Accuracy: 0.596800
# Epoch 84, CIFAR-10 Batch 5:  Loss:     0.2037, Validation Accuracy: 0.613800
# Epoch 85, CIFAR-10 Batch 1:  Loss:     0.1970, Validation Accuracy: 0.600200
# Epoch 85, CIFAR-10 Batch 2:  Loss:     0.2209, Validation Accuracy: 0.607400
# Epoch 85, CIFAR-10 Batch 3:  Loss:     0.2173, Validation Accuracy: 0.591400
# Epoch 85, CIFAR-10 Batch 4:  Loss:     0.1991, Validation Accuracy: 0.606200
# Epoch 85, CIFAR-10 Batch 5:  Loss:     0.1945, Validation Accuracy: 0.598400
# Epoch 86, CIFAR-10 Batch 1:  Loss:     0.1819, Validation Accuracy: 0.608200
# Epoch 86, CIFAR-10 Batch 2:  Loss:     0.1593, Validation Accuracy: 0.611800
# Epoch 86, CIFAR-10 Batch 3:  Loss:     0.1252, Validation Accuracy: 0.630400
# Epoch 86, CIFAR-10 Batch 4:  Loss:     0.1527, Validation Accuracy: 0.613600
# Epoch 86, CIFAR-10 Batch 5:  Loss:     0.1310, Validation Accuracy: 0.621600
# Epoch 87, CIFAR-10 Batch 1:  Loss:     0.1458, Validation Accuracy: 0.612200
# Epoch 87, CIFAR-10 Batch 2:  Loss:     0.1274, Validation Accuracy: 0.628000
# Epoch 87, CIFAR-10 Batch 3:  Loss:     0.1084, Validation Accuracy: 0.620200
# Epoch 87, CIFAR-10 Batch 4:  Loss:     0.1145, Validation Accuracy: 0.623800
# Epoch 87, CIFAR-10 Batch 5:  Loss:     0.0855, Validation Accuracy: 0.619000
# Epoch 88, CIFAR-10 Batch 1:  Loss:     0.1148, Validation Accuracy: 0.625400
# Epoch 88, CIFAR-10 Batch 2:  Loss:     0.1189, Validation Accuracy: 0.611000
# Epoch 88, CIFAR-10 Batch 3:  Loss:     0.1222, Validation Accuracy: 0.624200
# Epoch 88, CIFAR-10 Batch 4:  Loss:     0.1475, Validation Accuracy: 0.585200
# Epoch 88, CIFAR-10 Batch 5:  Loss:     0.1438, Validation Accuracy: 0.617800
# Epoch 89, CIFAR-10 Batch 1:  Loss:     0.1734, Validation Accuracy: 0.587800
# Epoch 89, CIFAR-10 Batch 2:  Loss:     0.1820, Validation Accuracy: 0.610400
# Epoch 89, CIFAR-10 Batch 3:  Loss:     0.2056, Validation Accuracy: 0.580000
# Epoch 89, CIFAR-10 Batch 4:  Loss:     0.2065, Validation Accuracy: 0.607000
# Epoch 89, CIFAR-10 Batch 5:  Loss:     0.1948, Validation Accuracy: 0.588400
# Epoch 90, CIFAR-10 Batch 1:  Loss:     0.1932, Validation Accuracy: 0.603600
# Epoch 90, CIFAR-10 Batch 2:  Loss:     0.1798, Validation Accuracy: 0.598600
# Epoch 90, CIFAR-10 Batch 3:  Loss:     0.1804, Validation Accuracy: 0.613200
# Epoch 90, CIFAR-10 Batch 4:  Loss:     0.1615, Validation Accuracy: 0.614200
# Epoch 90, CIFAR-10 Batch 5:  Loss:     0.1167, Validation Accuracy: 0.628000
# Epoch 91, CIFAR-10 Batch 1:  Loss:     0.1787, Validation Accuracy: 0.603600
# Epoch 91, CIFAR-10 Batch 2:  Loss:     0.1566, Validation Accuracy: 0.607400
# Epoch 91, CIFAR-10 Batch 3:  Loss:     0.1008, Validation Accuracy: 0.619800
# Epoch 91, CIFAR-10 Batch 4:  Loss:     0.0981, Validation Accuracy: 0.631000
# Epoch 91, CIFAR-10 Batch 5:  Loss:     0.0943, Validation Accuracy: 0.627000
# Epoch 92, CIFAR-10 Batch 1:  Loss:     0.1237, Validation Accuracy: 0.611800
# Epoch 92, CIFAR-10 Batch 2:  Loss:     0.0981, Validation Accuracy: 0.621800
# Epoch 92, CIFAR-10 Batch 3:  Loss:     0.0916, Validation Accuracy: 0.626200
# Epoch 92, CIFAR-10 Batch 4:  Loss:     0.0841, Validation Accuracy: 0.626400
# Epoch 92, CIFAR-10 Batch 5:  Loss:     0.0929, Validation Accuracy: 0.623400
# Epoch 93, CIFAR-10 Batch 1:  Loss:     0.1064, Validation Accuracy: 0.616000
# Epoch 93, CIFAR-10 Batch 2:  Loss:     0.0911, Validation Accuracy: 0.627000
# Epoch 93, CIFAR-10 Batch 3:  Loss:     0.0749, Validation Accuracy: 0.616400
# Epoch 93, CIFAR-10 Batch 4:  Loss:     0.0974, Validation Accuracy: 0.616400
# Epoch 93, CIFAR-10 Batch 5:  Loss:     0.1294, Validation Accuracy: 0.602600
# Epoch 94, CIFAR-10 Batch 1:  Loss:     0.1182, Validation Accuracy: 0.619800
# Epoch 94, CIFAR-10 Batch 2:  Loss:     0.0845, Validation Accuracy: 0.625400
# Epoch 94, CIFAR-10 Batch 3:  Loss:     0.1043, Validation Accuracy: 0.625200
# Epoch 94, CIFAR-10 Batch 4:  Loss:     0.1201, Validation Accuracy: 0.600800
# Epoch 94, CIFAR-10 Batch 5:  Loss:     0.1186, Validation Accuracy: 0.616800
# Epoch 95, CIFAR-10 Batch 1:  Loss:     0.1439, Validation Accuracy: 0.597000
# Epoch 95, CIFAR-10 Batch 2:  Loss:     0.1368, Validation Accuracy: 0.617600
# Epoch 95, CIFAR-10 Batch 3:  Loss:     0.1479, Validation Accuracy: 0.598200
# Epoch 95, CIFAR-10 Batch 4:  Loss:     0.1013, Validation Accuracy: 0.622600
# Epoch 95, CIFAR-10 Batch 5:  Loss:     0.0972, Validation Accuracy: 0.609200
# Epoch 96, CIFAR-10 Batch 1:  Loss:     0.1549, Validation Accuracy: 0.615400
# Epoch 96, CIFAR-10 Batch 2:  Loss:     0.1469, Validation Accuracy: 0.599800
# Epoch 96, CIFAR-10 Batch 3:  Loss:     0.1054, Validation Accuracy: 0.628800
# Epoch 96, CIFAR-10 Batch 4:  Loss:     0.1140, Validation Accuracy: 0.598200
# Epoch 96, CIFAR-10 Batch 5:  Loss:     0.1184, Validation Accuracy: 0.625000
# Epoch 97, CIFAR-10 Batch 1:  Loss:     0.1259, Validation Accuracy: 0.598600
# Epoch 97, CIFAR-10 Batch 2:  Loss:     0.1020, Validation Accuracy: 0.632600
# Epoch 97, CIFAR-10 Batch 3:  Loss:     0.0818, Validation Accuracy: 0.618200
# Epoch 97, CIFAR-10 Batch 4:  Loss:     0.1025, Validation Accuracy: 0.619800
# Epoch 97, CIFAR-10 Batch 5:  Loss:     0.0675, Validation Accuracy: 0.623800
# Epoch 98, CIFAR-10 Batch 1:  Loss:     0.0995, Validation Accuracy: 0.615600
# Epoch 98, CIFAR-10 Batch 2:  Loss:     0.0974, Validation Accuracy: 0.621400
# Epoch 98, CIFAR-10 Batch 3:  Loss:     0.0800, Validation Accuracy: 0.616000
# Epoch 98, CIFAR-10 Batch 4:  Loss:     0.0964, Validation Accuracy: 0.609400
# Epoch 98, CIFAR-10 Batch 5:  Loss:     0.0784, Validation Accuracy: 0.629800
# Epoch 99, CIFAR-10 Batch 1:  Loss:     0.0957, Validation Accuracy: 0.612000
# Epoch 99, CIFAR-10 Batch 2:  Loss:     0.0949, Validation Accuracy: 0.626800
# Epoch 99, CIFAR-10 Batch 3:  Loss:     0.0990, Validation Accuracy: 0.613000
# Epoch 99, CIFAR-10 Batch 4:  Loss:     0.0991, Validation Accuracy: 0.613800
# Epoch 99, CIFAR-10 Batch 5:  Loss:     0.0706, Validation Accuracy: 0.621400
# Epoch 100, CIFAR-10 Batch 1:  Loss:     0.0878, Validation Accuracy: 0.625000
# Epoch 100, CIFAR-10 Batch 2:  Loss:     0.0913, Validation Accuracy: 0.620800
# Epoch 100, CIFAR-10 Batch 3:  Loss:     0.0880, Validation Accuracy: 0.622000
# Epoch 100, CIFAR-10 Batch 4:  Loss:     0.0647, Validation Accuracy: 0.620000
# Epoch 100, CIFAR-10 Batch 5:  Loss:     0.0647, Validation Accuracy: 0.630000
# Epoch 101, CIFAR-10 Batch 1:  Loss:     0.0908, Validation Accuracy: 0.614400
# Epoch 101, CIFAR-10 Batch 2:  Loss:     0.1040, Validation Accuracy: 0.612400
# Epoch 101, CIFAR-10 Batch 3:  Loss:     0.0958, Validation Accuracy: 0.622600
# Epoch 101, CIFAR-10 Batch 4:  Loss:     0.0705, Validation Accuracy: 0.628400
# Epoch 101, CIFAR-10 Batch 5:  Loss:     0.0697, Validation Accuracy: 0.612200
# Epoch 102, CIFAR-10 Batch 1:  Loss:     0.0901, Validation Accuracy: 0.626600
# Epoch 102, CIFAR-10 Batch 2:  Loss:     0.0814, Validation Accuracy: 0.629600
# Epoch 102, CIFAR-10 Batch 3:  Loss:     0.0817, Validation Accuracy: 0.628000
# Epoch 102, CIFAR-10 Batch 4:  Loss:     0.0736, Validation Accuracy: 0.607800
# Epoch 102, CIFAR-10 Batch 5:  Loss:     0.0990, Validation Accuracy: 0.616200
# Epoch 103, CIFAR-10 Batch 1:  Loss:     0.1093, Validation Accuracy: 0.605600
# Epoch 103, CIFAR-10 Batch 2:  Loss:     0.1053, Validation Accuracy: 0.621800
# Epoch 103, CIFAR-10 Batch 3:  Loss:     0.0909, Validation Accuracy: 0.615200
# Epoch 103, CIFAR-10 Batch 4:  Loss:     0.0719, Validation Accuracy: 0.629000
# Epoch 103, CIFAR-10 Batch 5:  Loss:     0.0699, Validation Accuracy: 0.622800
# Epoch 104, CIFAR-10 Batch 1:  Loss:     0.0916, Validation Accuracy: 0.632800
# Epoch 104, CIFAR-10 Batch 2:  Loss:     0.0709, Validation Accuracy: 0.628800
# Epoch 104, CIFAR-10 Batch 3:  Loss:     0.0711, Validation Accuracy: 0.629600
# Epoch 104, CIFAR-10 Batch 4:  Loss:     0.0853, Validation Accuracy: 0.593400
# Epoch 104, CIFAR-10 Batch 5:  Loss:     0.0946, Validation Accuracy: 0.619600
# Epoch 105, CIFAR-10 Batch 1:  Loss:     0.0940, Validation Accuracy: 0.616600
# Epoch 105, CIFAR-10 Batch 2:  Loss:     0.0806, Validation Accuracy: 0.627000
# Epoch 105, CIFAR-10 Batch 3:  Loss:     0.0811, Validation Accuracy: 0.618600
# Epoch 105, CIFAR-10 Batch 4:  Loss:     0.0795, Validation Accuracy: 0.606800
# Epoch 105, CIFAR-10 Batch 5:  Loss:     0.1013, Validation Accuracy: 0.610200
# Epoch 106, CIFAR-10 Batch 1:  Loss:     0.1348, Validation Accuracy: 0.606800
# Epoch 106, CIFAR-10 Batch 2:  Loss:     0.1523, Validation Accuracy: 0.592600
# Epoch 106, CIFAR-10 Batch 3:  Loss:     0.1161, Validation Accuracy: 0.602400
# Epoch 106, CIFAR-10 Batch 4:  Loss:     0.1147, Validation Accuracy: 0.581600
# Epoch 106, CIFAR-10 Batch 5:  Loss:     0.0669, Validation Accuracy: 0.633200
# Epoch 107, CIFAR-10 Batch 1:  Loss:     0.0881, Validation Accuracy: 0.625600
# Epoch 107, CIFAR-10 Batch 2:  Loss:     0.0818, Validation Accuracy: 0.615600
# Epoch 107, CIFAR-10 Batch 3:  Loss:     0.0710, Validation Accuracy: 0.624800
# Epoch 107, CIFAR-10 Batch 4:  Loss:     0.0673, Validation Accuracy: 0.616800
# Epoch 107, CIFAR-10 Batch 5:  Loss:     0.0587, Validation Accuracy: 0.622600
# Epoch 108, CIFAR-10 Batch 1:  Loss:     0.0664, Validation Accuracy: 0.635800
# Epoch 108, CIFAR-10 Batch 2:  Loss:     0.0495, Validation Accuracy: 0.632000
# Epoch 108, CIFAR-10 Batch 3:  Loss:     0.0684, Validation Accuracy: 0.627600
# Epoch 108, CIFAR-10 Batch 4:  Loss:     0.0644, Validation Accuracy: 0.614200
# Epoch 108, CIFAR-10 Batch 5:  Loss:     0.0723, Validation Accuracy: 0.617400
# Epoch 109, CIFAR-10 Batch 1:  Loss:     0.0779, Validation Accuracy: 0.626400
# Epoch 109, CIFAR-10 Batch 2:  Loss:     0.0538, Validation Accuracy: 0.626800
# Epoch 109, CIFAR-10 Batch 3:  Loss:     0.0536, Validation Accuracy: 0.632400
# Epoch 109, CIFAR-10 Batch 4:  Loss:     0.0573, Validation Accuracy: 0.612800
# Epoch 109, CIFAR-10 Batch 5:  Loss:     0.0420, Validation Accuracy: 0.625000
# Epoch 110, CIFAR-10 Batch 1:  Loss:     0.0545, Validation Accuracy: 0.634000
# Epoch 110, CIFAR-10 Batch 2:  Loss:     0.0426, Validation Accuracy: 0.624200
# Epoch 110, CIFAR-10 Batch 3:  Loss:     0.0624, Validation Accuracy: 0.622400
# Epoch 110, CIFAR-10 Batch 4:  Loss:     0.0535, Validation Accuracy: 0.611800
# Epoch 110, CIFAR-10 Batch 5:  Loss:     0.0309, Validation Accuracy: 0.627600
# Epoch 111, CIFAR-10 Batch 1:  Loss:     0.0626, Validation Accuracy: 0.626200
# Epoch 111, CIFAR-10 Batch 2:  Loss:     0.0564, Validation Accuracy: 0.612000
# Epoch 111, CIFAR-10 Batch 3:  Loss:     0.0673, Validation Accuracy: 0.619400
# Epoch 111, CIFAR-10 Batch 4:  Loss:     0.0586, Validation Accuracy: 0.621200
# Epoch 111, CIFAR-10 Batch 5:  Loss:     0.0364, Validation Accuracy: 0.624600
# Epoch 112, CIFAR-10 Batch 1:  Loss:     0.0676, Validation Accuracy: 0.620400
# Epoch 112, CIFAR-10 Batch 2:  Loss:     0.0694, Validation Accuracy: 0.611200
# Epoch 112, CIFAR-10 Batch 3:  Loss:     0.0727, Validation Accuracy: 0.622600
# Epoch 112, CIFAR-10 Batch 4:  Loss:     0.0572, Validation Accuracy: 0.624200
# Epoch 112, CIFAR-10 Batch 5:  Loss:     0.0385, Validation Accuracy: 0.626800
# Epoch 113, CIFAR-10 Batch 1:  Loss:     0.0645, Validation Accuracy: 0.617800
# Epoch 113, CIFAR-10 Batch 2:  Loss:     0.0954, Validation Accuracy: 0.606000
# Epoch 113, CIFAR-10 Batch 3:  Loss:     0.0835, Validation Accuracy: 0.619600
# Epoch 113, CIFAR-10 Batch 4:  Loss:     0.0674, Validation Accuracy: 0.627000
# Epoch 113, CIFAR-10 Batch 5:  Loss:     0.0635, Validation Accuracy: 0.612200
# Epoch 114, CIFAR-10 Batch 1:  Loss:     0.0731, Validation Accuracy: 0.621400
# Epoch 114, CIFAR-10 Batch 2:  Loss:     0.0565, Validation Accuracy: 0.620600
# Epoch 114, CIFAR-10 Batch 3:  Loss:     0.0624, Validation Accuracy: 0.635400
# Epoch 114, CIFAR-10 Batch 4:  Loss:     0.0714, Validation Accuracy: 0.625000
# Epoch 114, CIFAR-10 Batch 5:  Loss:     0.0428, Validation Accuracy: 0.621200
# Epoch 115, CIFAR-10 Batch 1:  Loss:     0.0594, Validation Accuracy: 0.632000
# Epoch 115, CIFAR-10 Batch 2:  Loss:     0.0499, Validation Accuracy: 0.634000
# Epoch 115, CIFAR-10 Batch 3:  Loss:     0.0465, Validation Accuracy: 0.623800
# Epoch 115, CIFAR-10 Batch 4:  Loss:     0.0400, Validation Accuracy: 0.637600
# Epoch 115, CIFAR-10 Batch 5:  Loss:     0.0312, Validation Accuracy: 0.621600
# Epoch 116, CIFAR-10 Batch 1:  Loss:     0.0607, Validation Accuracy: 0.627400
# Epoch 116, CIFAR-10 Batch 2:  Loss:     0.0763, Validation Accuracy: 0.609400
# Epoch 116, CIFAR-10 Batch 3:  Loss:     0.0550, Validation Accuracy: 0.625600
# Epoch 116, CIFAR-10 Batch 4:  Loss:     0.0502, Validation Accuracy: 0.618200
# Epoch 116, CIFAR-10 Batch 5:  Loss:     0.0568, Validation Accuracy: 0.614200
# Epoch 117, CIFAR-10 Batch 1:  Loss:     0.0796, Validation Accuracy: 0.612600
# Epoch 117, CIFAR-10 Batch 2:  Loss:     0.0611, Validation Accuracy: 0.624000
# Epoch 117, CIFAR-10 Batch 3:  Loss:     0.0622, Validation Accuracy: 0.612400
# Epoch 117, CIFAR-10 Batch 4:  Loss:     0.0834, Validation Accuracy: 0.614800
# Epoch 117, CIFAR-10 Batch 5:  Loss:     0.0920, Validation Accuracy: 0.600000
# Epoch 118, CIFAR-10 Batch 1:  Loss:     0.0720, Validation Accuracy: 0.622800
# Epoch 118, CIFAR-10 Batch 2:  Loss:     0.0466, Validation Accuracy: 0.627600
# Epoch 118, CIFAR-10 Batch 3:  Loss:     0.0546, Validation Accuracy: 0.627600
# Epoch 118, CIFAR-10 Batch 4:  Loss:     0.0588, Validation Accuracy: 0.616600
# Epoch 118, CIFAR-10 Batch 5:  Loss:     0.0507, Validation Accuracy: 0.621200
# Epoch 119, CIFAR-10 Batch 1:  Loss:     0.0711, Validation Accuracy: 0.615600
# Epoch 119, CIFAR-10 Batch 2:  Loss:     0.0437, Validation Accuracy: 0.629800
# Epoch 119, CIFAR-10 Batch 3:  Loss:     0.0395, Validation Accuracy: 0.622800
# Epoch 119, CIFAR-10 Batch 4:  Loss:     0.0393, Validation Accuracy: 0.630400
# Epoch 119, CIFAR-10 Batch 5:  Loss:     0.0365, Validation Accuracy: 0.619400
# Epoch 120, CIFAR-10 Batch 1:  Loss:     0.0492, Validation Accuracy: 0.632000
# Epoch 120, CIFAR-10 Batch 2:  Loss:     0.0330, Validation Accuracy: 0.626200
# Epoch 120, CIFAR-10 Batch 3:  Loss:     0.0578, Validation Accuracy: 0.609800
# Epoch 120, CIFAR-10 Batch 4:  Loss:     0.0596, Validation Accuracy: 0.608200
# Epoch 120, CIFAR-10 Batch 5:  Loss:     0.0864, Validation Accuracy: 0.596200
# Epoch 121, CIFAR-10 Batch 1:  Loss:     0.1318, Validation Accuracy: 0.598200
# Epoch 121, CIFAR-10 Batch 2:  Loss:     0.0722, Validation Accuracy: 0.607000
# Epoch 121, CIFAR-10 Batch 3:  Loss:     0.0832, Validation Accuracy: 0.604200
# Epoch 121, CIFAR-10 Batch 4:  Loss:     0.1334, Validation Accuracy: 0.594600
# Epoch 121, CIFAR-10 Batch 5:  Loss:     0.2056, Validation Accuracy: 0.575800
# Epoch 122, CIFAR-10 Batch 1:  Loss:     0.1807, Validation Accuracy: 0.592000
# Epoch 122, CIFAR-10 Batch 2:  Loss:     0.1228, Validation Accuracy: 0.608400
# Epoch 122, CIFAR-10 Batch 3:  Loss:     0.0691, Validation Accuracy: 0.622800
# Epoch 122, CIFAR-10 Batch 4:  Loss:     0.0674, Validation Accuracy: 0.619600
# Epoch 122, CIFAR-10 Batch 5:  Loss:     0.0769, Validation Accuracy: 0.615600
# Epoch 123, CIFAR-10 Batch 1:  Loss:     0.0763, Validation Accuracy: 0.613400
# Epoch 123, CIFAR-10 Batch 2:  Loss:     0.0595, Validation Accuracy: 0.623600
# Epoch 123, CIFAR-10 Batch 3:  Loss:     0.0735, Validation Accuracy: 0.608000
# Epoch 123, CIFAR-10 Batch 4:  Loss:     0.0838, Validation Accuracy: 0.611400
# Epoch 123, CIFAR-10 Batch 5:  Loss:     0.0530, Validation Accuracy: 0.612600
# Epoch 124, CIFAR-10 Batch 1:  Loss:     0.0560, Validation Accuracy: 0.624200
# Epoch 124, CIFAR-10 Batch 2:  Loss:     0.0653, Validation Accuracy: 0.620200
# Epoch 124, CIFAR-10 Batch 3:  Loss:     0.1133, Validation Accuracy: 0.603000
# Epoch 124, CIFAR-10 Batch 4:  Loss:     0.1395, Validation Accuracy: 0.584600
# Epoch 124, CIFAR-10 Batch 5:  Loss:     0.1349, Validation Accuracy: 0.591800
# Epoch 125, CIFAR-10 Batch 1:  Loss:     0.1844, Validation Accuracy: 0.582200
# ...
# Epoch 160, CIFAR-10 Batch 1:  Loss:     0.0442, Validation Accuracy: 0.619000
# Epoch 160, CIFAR-10 Batch 2:  Loss:     0.0238, Validation Accuracy: 0.622200
# Epoch 160, CIFAR-10 Batch 3:  Loss:     0.0348, Validation Accuracy: 0.614600
# Epoch 160, CIFAR-10 Batch 4:  Loss:     0.0330, Validation Accuracy: 0.615200
# Epoch 160, CIFAR-10 Batch 5:  Loss:     0.0280, Validation Accuracy: 0.599200
# Epoch 161, CIFAR-10 Batch 1:  Loss:     0.0371, Validation Accuracy: 0.626000
# Epoch 161, CIFAR-10 Batch 2:  Loss:     0.0192, Validation Accuracy: 0.636800
# Epoch 161, CIFAR-10 Batch 3:  Loss:     0.0216, Validation Accuracy: 0.623800
# Epoch 161, CIFAR-10 Batch 4:  Loss:     0.0394, Validation Accuracy: 0.618800
# Epoch 161, CIFAR-10 Batch 5:  Loss:     0.0163, Validation Accuracy: 0.608600
# Epoch 162, CIFAR-10 Batch 1:  Loss:     0.0194, Validation Accuracy: 0.625800
# Epoch 162, CIFAR-10 Batch 2:  Loss:     0.0155, Validation Accuracy: 0.628000
# Epoch 162, CIFAR-10 Batch 3:  Loss:     0.0228, Validation Accuracy: 0.621400
# Epoch 162, CIFAR-10 Batch 4:  Loss:     0.0221, Validation Accuracy: 0.629800
# Epoch 162, CIFAR-10 Batch 5:  Loss:     0.0138, Validation Accuracy: 0.624600
# Epoch 163, CIFAR-10 Batch 1:  Loss:     0.0335, Validation Accuracy: 0.604800
# Epoch 163, CIFAR-10 Batch 2:  Loss:     0.0269, Validation Accuracy: 0.621600
# Epoch 163, CIFAR-10 Batch 3:  Loss:     0.0237, Validation Accuracy: 0.617200
# Epoch 163, CIFAR-10 Batch 4:  Loss:     0.0203, Validation Accuracy: 0.623800
# Epoch 163, CIFAR-10 Batch 5:  Loss:     0.0196, Validation Accuracy: 0.616000
# Epoch 164, CIFAR-10 Batch 1:  Loss:     0.0336, Validation Accuracy: 0.621600
# Epoch 164, CIFAR-10 Batch 2:  Loss:     0.0117, Validation Accuracy: 0.624200
# Epoch 164, CIFAR-10 Batch 3:  Loss:     0.0159, Validation Accuracy: 0.631000
# Epoch 164, CIFAR-10 Batch 4:  Loss:     0.0156, Validation Accuracy: 0.631800
# Epoch 164, CIFAR-10 Batch 5:  Loss:     0.0078, Validation Accuracy: 0.633800
# Epoch 165, CIFAR-10 Batch 1:  Loss:     0.0123, Validation Accuracy: 0.627000
# Epoch 165, CIFAR-10 Batch 2:  Loss:     0.0090, Validation Accuracy: 0.632400
# Epoch 165, CIFAR-10 Batch 3:  Loss:     0.0073, Validation Accuracy: 0.627200
# Epoch 165, CIFAR-10 Batch 4:  Loss:     0.0116, Validation Accuracy: 0.638200
# Epoch 165, CIFAR-10 Batch 5:  Loss:     0.0049, Validation Accuracy: 0.630800
# Epoch 166, CIFAR-10 Batch 1:  Loss:     0.0074, Validation Accuracy: 0.634400
# Epoch 166, CIFAR-10 Batch 2:  Loss:     0.0061, Validation Accuracy: 0.637200
# Epoch 166, CIFAR-10 Batch 3:  Loss:     0.0058, Validation Accuracy: 0.627800
# Epoch 166, CIFAR-10 Batch 4:  Loss:     0.0044, Validation Accuracy: 0.632600
# Epoch 166, CIFAR-10 Batch 5:  Loss:     0.0028, Validation Accuracy: 0.634800
# Epoch 167, CIFAR-10 Batch 1:  Loss:     0.0051, Validation Accuracy: 0.633400
# Epoch 167, CIFAR-10 Batch 2:  Loss:     0.0051, Validation Accuracy: 0.638400
# Epoch 167, CIFAR-10 Batch 3:  Loss:     0.0045, Validation Accuracy: 0.628800
# Epoch 167, CIFAR-10 Batch 4:  Loss:     0.0032, Validation Accuracy: 0.632400
# Epoch 167, CIFAR-10 Batch 5:  Loss:     0.0024, Validation Accuracy: 0.632600
# Epoch 168, CIFAR-10 Batch 1:  Loss:     0.0037, Validation Accuracy: 0.630400
# Epoch 168, CIFAR-10 Batch 2:  Loss:     0.0024, Validation Accuracy: 0.641200
# Epoch 168, CIFAR-10 Batch 3:  Loss:     0.0033, Validation Accuracy: 0.636600
# Epoch 168, CIFAR-10 Batch 4:  Loss:     0.0033, Validation Accuracy: 0.633800
# Epoch 168, CIFAR-10 Batch 5:  Loss:     0.0025, Validation Accuracy: 0.628200
# Epoch 169, CIFAR-10 Batch 1:  Loss:     0.0038, Validation Accuracy: 0.628400
# Epoch 169, CIFAR-10 Batch 2:  Loss:     0.0019, Validation Accuracy: 0.635600
# Epoch 169, CIFAR-10 Batch 3:  Loss:     0.0028, Validation Accuracy: 0.638200
# Epoch 169, CIFAR-10 Batch 4:  Loss:     0.0028, Validation Accuracy: 0.634400
# Epoch 169, CIFAR-10 Batch 5:  Loss:     0.0013, Validation Accuracy: 0.630200
# Epoch 170, CIFAR-10 Batch 1:  Loss:     0.0026, Validation Accuracy: 0.637800
# Epoch 170, CIFAR-10 Batch 2:  Loss:     0.0019, Validation Accuracy: 0.639200
# Epoch 170, CIFAR-10 Batch 3:  Loss:     0.0027, Validation Accuracy: 0.632600
# Epoch 170, CIFAR-10 Batch 4:  Loss:     0.0028, Validation Accuracy: 0.636800
# Epoch 170, CIFAR-10 Batch 5:  Loss:     0.0013, Validation Accuracy: 0.631800
# Epoch 171, CIFAR-10 Batch 1:  Loss:     0.0025, Validation Accuracy: 0.633400
# Epoch 171, CIFAR-10 Batch 2:  Loss:     0.0021, Validation Accuracy: 0.632800
# Epoch 171, CIFAR-10 Batch 3:  Loss:     0.0019, Validation Accuracy: 0.635600
# Epoch 171, CIFAR-10 Batch 4:  Loss:     0.0020, Validation Accuracy: 0.636000
# Epoch 171, CIFAR-10 Batch 5:  Loss:     0.0010, Validation Accuracy: 0.635200
# Epoch 172, CIFAR-10 Batch 1:  Loss:     0.0027, Validation Accuracy: 0.630400
# Epoch 172, CIFAR-10 Batch 2:  Loss:     0.0028, Validation Accuracy: 0.625400
# Epoch 172, CIFAR-10 Batch 3:  Loss:     0.0032, Validation Accuracy: 0.629400
# Epoch 172, CIFAR-10 Batch 4:  Loss:     0.0022, Validation Accuracy: 0.636200
# Epoch 172, CIFAR-10 Batch 5:  Loss:     0.0009, Validation Accuracy: 0.633000
# Epoch 173, CIFAR-10 Batch 1:  Loss:     0.0028, Validation Accuracy: 0.631200
# Epoch 173, CIFAR-10 Batch 2:  Loss:     0.0029, Validation Accuracy: 0.624200
# Epoch 173, CIFAR-10 Batch 3:  Loss:     0.0031, Validation Accuracy: 0.627000
# Epoch 173, CIFAR-10 Batch 4:  Loss:     0.0035, Validation Accuracy: 0.631400
# Epoch 173, CIFAR-10 Batch 5:  Loss:     0.0014, Validation Accuracy: 0.633200
# Epoch 174, CIFAR-10 Batch 1:  Loss:     0.0025, Validation Accuracy: 0.632000
# Epoch 174, CIFAR-10 Batch 2:  Loss:     0.0028, Validation Accuracy: 0.627800
# Epoch 174, CIFAR-10 Batch 3:  Loss:     0.0017, Validation Accuracy: 0.630200
# Epoch 174, CIFAR-10 Batch 4:  Loss:     0.0030, Validation Accuracy: 0.625600
# Epoch 174, CIFAR-10 Batch 5:  Loss:     0.0019, Validation Accuracy: 0.627200
# Epoch 175, CIFAR-10 Batch 1:  Loss:     0.0050, Validation Accuracy: 0.621200
# Epoch 175, CIFAR-10 Batch 2:  Loss:     0.0042, Validation Accuracy: 0.621600
# Epoch 175, CIFAR-10 Batch 3:  Loss:     0.0038, Validation Accuracy: 0.630600
# Epoch 175, CIFAR-10 Batch 4:  Loss:     0.0036, Validation Accuracy: 0.618000
# Epoch 175, CIFAR-10 Batch 5:  Loss:     0.0042, Validation Accuracy: 0.618400
# Epoch 176, CIFAR-10 Batch 1:  Loss:     0.0088, Validation Accuracy: 0.626400
# Epoch 176, CIFAR-10 Batch 2:  Loss:     0.0025, Validation Accuracy: 0.629000
# Epoch 176, CIFAR-10 Batch 3:  Loss:     0.0057, Validation Accuracy: 0.636800
# Epoch 176, CIFAR-10 Batch 4:  Loss:     0.0055, Validation Accuracy: 0.617200
# Epoch 176, CIFAR-10 Batch 5:  Loss:     0.0043, Validation Accuracy: 0.620800
# Epoch 177, CIFAR-10 Batch 1:  Loss:     0.0083, Validation Accuracy: 0.615200
# Epoch 177, CIFAR-10 Batch 2:  Loss:     0.0072, Validation Accuracy: 0.616000
# Epoch 177, CIFAR-10 Batch 3:  Loss:     0.0104, Validation Accuracy: 0.623800
# Epoch 177, CIFAR-10 Batch 4:  Loss:     0.0100, Validation Accuracy: 0.606600
# Epoch 177, CIFAR-10 Batch 5:  Loss:     0.0052, Validation Accuracy: 0.618800
# Epoch 178, CIFAR-10 Batch 1:  Loss:     0.0084, Validation Accuracy: 0.619200
# Epoch 178, CIFAR-10 Batch 2:  Loss:     0.0053, Validation Accuracy: 0.621400
# Epoch 178, CIFAR-10 Batch 3:  Loss:     0.0141, Validation Accuracy: 0.625200
# Epoch 178, CIFAR-10 Batch 4:  Loss:     0.0182, Validation Accuracy: 0.610200
# Epoch 178, CIFAR-10 Batch 5:  Loss:     0.0261, Validation Accuracy: 0.599200
# Epoch 179, CIFAR-10 Batch 1:  Loss:     0.0242, Validation Accuracy: 0.609600
# Epoch 179, CIFAR-10 Batch 2:  Loss:     0.0141, Validation Accuracy: 0.608000
# Epoch 179, CIFAR-10 Batch 3:  Loss:     0.0160, Validation Accuracy: 0.627000
# Epoch 179, CIFAR-10 Batch 4:  Loss:     0.0284, Validation Accuracy: 0.609000
# Epoch 179, CIFAR-10 Batch 5:  Loss:     0.0156, Validation Accuracy: 0.614000
# Epoch 180, CIFAR-10 Batch 1:  Loss:     0.0249, Validation Accuracy: 0.616600
# Epoch 180, CIFAR-10 Batch 2:  Loss:     0.0254, Validation Accuracy: 0.610200
# Epoch 180, CIFAR-10 Batch 3:  Loss:     0.0359, Validation Accuracy: 0.610000
# Epoch 180, CIFAR-10 Batch 4:  Loss:     0.0368, Validation Accuracy: 0.604800
# Epoch 180, CIFAR-10 Batch 5:  Loss:     0.0073, Validation Accuracy: 0.612200
# Epoch 181, CIFAR-10 Batch 1:  Loss:     0.0247, Validation Accuracy: 0.620000
# Epoch 181, CIFAR-10 Batch 2:  Loss:     0.0124, Validation Accuracy: 0.613800
# Epoch 181, CIFAR-10 Batch 3:  Loss:     0.0180, Validation Accuracy: 0.619200
# Epoch 181, CIFAR-10 Batch 4:  Loss:     0.0219, Validation Accuracy: 0.620400
# Epoch 181, CIFAR-10 Batch 5:  Loss:     0.0080, Validation Accuracy: 0.610600
# Epoch 182, CIFAR-10 Batch 1:  Loss:     0.0080, Validation Accuracy: 0.626600
# Epoch 182, CIFAR-10 Batch 2:  Loss:     0.0047, Validation Accuracy: 0.621000
# Epoch 182, CIFAR-10 Batch 3:  Loss:     0.0059, Validation Accuracy: 0.626000
# Epoch 182, CIFAR-10 Batch 4:  Loss:     0.0053, Validation Accuracy: 0.629400
# Epoch 182, CIFAR-10 Batch 5:  Loss:     0.0069, Validation Accuracy: 0.611000
# Epoch 183, CIFAR-10 Batch 1:  Loss:     0.0077, Validation Accuracy: 0.626800
# Epoch 183, CIFAR-10 Batch 2:  Loss:     0.0142, Validation Accuracy: 0.615800
# Epoch 183, CIFAR-10 Batch 3:  Loss:     0.0167, Validation Accuracy: 0.611400
# Epoch 183, CIFAR-10 Batch 4:  Loss:     0.0068, Validation Accuracy: 0.624400
# Epoch 183, CIFAR-10 Batch 5:  Loss:     0.0030, Validation Accuracy: 0.615800
# Epoch 184, CIFAR-10 Batch 1:  Loss:     0.0183, Validation Accuracy: 0.615400
# Epoch 184, CIFAR-10 Batch 2:  Loss:     0.0072, Validation Accuracy: 0.616600
# Epoch 184, CIFAR-10 Batch 3:  Loss:     0.0069, Validation Accuracy: 0.622600
# Epoch 184, CIFAR-10 Batch 4:  Loss:     0.0041, Validation Accuracy: 0.626800
# Epoch 184, CIFAR-10 Batch 5:  Loss:     0.0059, Validation Accuracy: 0.613600
# Epoch 185, CIFAR-10 Batch 1:  Loss:     0.0056, Validation Accuracy: 0.620200
# Epoch 185, CIFAR-10 Batch 2:  Loss:     0.0025, Validation Accuracy: 0.630600
# Epoch 185, CIFAR-10 Batch 3:  Loss:     0.0049, Validation Accuracy: 0.620200
# Epoch 185, CIFAR-10 Batch 4:  Loss:     0.0167, Validation Accuracy: 0.629200
# Epoch 185, CIFAR-10 Batch 5:  Loss:     0.0085, Validation Accuracy: 0.620600
# Epoch 186, CIFAR-10 Batch 1:  Loss:     0.0037, Validation Accuracy: 0.629800
# Epoch 186, CIFAR-10 Batch 2:  Loss:     0.0052, Validation Accuracy: 0.624600
# Epoch 186, CIFAR-10 Batch 3:  Loss:     0.0076, Validation Accuracy: 0.615600
# Epoch 186, CIFAR-10 Batch 4:  Loss:     0.0063, Validation Accuracy: 0.625400
# Epoch 186, CIFAR-10 Batch 5:  Loss:     0.0060, Validation Accuracy: 0.624400
# Epoch 187, CIFAR-10 Batch 1:  Loss:     0.0036, Validation Accuracy: 0.628400
# Epoch 187, CIFAR-10 Batch 2:  Loss:     0.0045, Validation Accuracy: 0.633200
# Epoch 187, CIFAR-10 Batch 3:  Loss:     0.0118, Validation Accuracy: 0.610600
# Epoch 187, CIFAR-10 Batch 4:  Loss:     0.0142, Validation Accuracy: 0.620800
# Epoch 187, CIFAR-10 Batch 5:  Loss:     0.0271, Validation Accuracy: 0.615400
# Epoch 188, CIFAR-10 Batch 1:  Loss:     0.0076, Validation Accuracy: 0.616400
# Epoch 188, CIFAR-10 Batch 2:  Loss:     0.0133, Validation Accuracy: 0.618200
# Epoch 188, CIFAR-10 Batch 3:  Loss:     0.0156, Validation Accuracy: 0.605000
# Epoch 188, CIFAR-10 Batch 4:  Loss:     0.0091, Validation Accuracy: 0.628400
# Epoch 188, CIFAR-10 Batch 5:  Loss:     0.0082, Validation Accuracy: 0.625400
# Epoch 189, CIFAR-10 Batch 1:  Loss:     0.0202, Validation Accuracy: 0.616400
# Epoch 189, CIFAR-10 Batch 2:  Loss:     0.0294, Validation Accuracy: 0.617400
# Epoch 189, CIFAR-10 Batch 3:  Loss:     0.0181, Validation Accuracy: 0.606800
# Epoch 189, CIFAR-10 Batch 4:  Loss:     0.0101, Validation Accuracy: 0.620200
# Epoch 189, CIFAR-10 Batch 5:  Loss:     0.0036, Validation Accuracy: 0.623200
# Epoch 190, CIFAR-10 Batch 1:  Loss:     0.0072, Validation Accuracy: 0.615200
# Epoch 190, CIFAR-10 Batch 2:  Loss:     0.0045, Validation Accuracy: 0.628800
# Epoch 190, CIFAR-10 Batch 3:  Loss:     0.0038, Validation Accuracy: 0.628200
# Epoch 190, CIFAR-10 Batch 4:  Loss:     0.0060, Validation Accuracy: 0.615400
# Epoch 190, CIFAR-10 Batch 5:  Loss:     0.0062, Validation Accuracy: 0.627800
# Epoch 191, CIFAR-10 Batch 1:  Loss:     0.0044, Validation Accuracy: 0.625600
# Epoch 191, CIFAR-10 Batch 2:  Loss:     0.0025, Validation Accuracy: 0.629800
# Epoch 191, CIFAR-10 Batch 3:  Loss:     0.0035, Validation Accuracy: 0.627400
# Epoch 191, CIFAR-10 Batch 4:  Loss:     0.0036, Validation Accuracy: 0.625200
# Epoch 191, CIFAR-10 Batch 5:  Loss:     0.0032, Validation Accuracy: 0.624400
# Epoch 192, CIFAR-10 Batch 1:  Loss:     0.0024, Validation Accuracy: 0.635600
# Epoch 192, CIFAR-10 Batch 2:  Loss:     0.0012, Validation Accuracy: 0.634400
# Epoch 192, CIFAR-10 Batch 3:  Loss:     0.0017, Validation Accuracy: 0.629400
# Epoch 192, CIFAR-10 Batch 4:  Loss:     0.0016, Validation Accuracy: 0.630400
# Epoch 192, CIFAR-10 Batch 5:  Loss:     0.0007, Validation Accuracy: 0.630000
# Epoch 193, CIFAR-10 Batch 1:  Loss:     0.0015, Validation Accuracy: 0.628000
# Epoch 193, CIFAR-10 Batch 2:  Loss:     0.0014, Validation Accuracy: 0.627200
# Epoch 193, CIFAR-10 Batch 3:  Loss:     0.0010, Validation Accuracy: 0.629200
# Epoch 193, CIFAR-10 Batch 4:  Loss:     0.0006, Validation Accuracy: 0.634400
# Epoch 193, CIFAR-10 Batch 5:  Loss:     0.0009, Validation Accuracy: 0.627600
# Epoch 194, CIFAR-10 Batch 1:  Loss:     0.0016, Validation Accuracy: 0.629600
# Epoch 194, CIFAR-10 Batch 2:  Loss:     0.0011, Validation Accuracy: 0.632200
# Epoch 194, CIFAR-10 Batch 3:  Loss:     0.0008, Validation Accuracy: 0.634000
# Epoch 194, CIFAR-10 Batch 4:  Loss:     0.0006, Validation Accuracy: 0.635600
# Epoch 194, CIFAR-10 Batch 5:  Loss:     0.0011, Validation Accuracy: 0.628200
# Epoch 195, CIFAR-10 Batch 1:  Loss:     0.0010, Validation Accuracy: 0.630400
# Epoch 195, CIFAR-10 Batch 2:  Loss:     0.0006, Validation Accuracy: 0.633000
# Epoch 195, CIFAR-10 Batch 3:  Loss:     0.0013, Validation Accuracy: 0.631000
# Epoch 195, CIFAR-10 Batch 4:  Loss:     0.0006, Validation Accuracy: 0.635000
# Epoch 195, CIFAR-10 Batch 5:  Loss:     0.0007, Validation Accuracy: 0.638600
# Epoch 196, CIFAR-10 Batch 1:  Loss:     0.0014, Validation Accuracy: 0.629600
# Epoch 196, CIFAR-10 Batch 2:  Loss:     0.0010, Validation Accuracy: 0.628400
# Epoch 196, CIFAR-10 Batch 3:  Loss:     0.0008, Validation Accuracy: 0.629000
# Epoch 196, CIFAR-10 Batch 4:  Loss:     0.0006, Validation Accuracy: 0.633600
# Epoch 196, CIFAR-10 Batch 5:  Loss:     0.0013, Validation Accuracy: 0.634400
# Epoch 197, CIFAR-10 Batch 1:  Loss:     0.0010, Validation Accuracy: 0.628600
# Epoch 197, CIFAR-10 Batch 2:  Loss:     0.0004, Validation Accuracy: 0.637600
# Epoch 197, CIFAR-10 Batch 3:  Loss:     0.0009, Validation Accuracy: 0.632800
# Epoch 197, CIFAR-10 Batch 4:  Loss:     0.0014, Validation Accuracy: 0.632000
# Epoch 197, CIFAR-10 Batch 5:  Loss:     0.0006, Validation Accuracy: 0.632800
# Epoch 198, CIFAR-10 Batch 1:  Loss:     0.0010, Validation Accuracy: 0.628400
# Epoch 198, CIFAR-10 Batch 2:  Loss:     0.0005, Validation Accuracy: 0.628600
# Epoch 198, CIFAR-10 Batch 3:  Loss:     0.0012, Validation Accuracy: 0.635000
# Epoch 198, CIFAR-10 Batch 4:  Loss:     0.0015, Validation Accuracy: 0.629400
# Epoch 198, CIFAR-10 Batch 5:  Loss:     0.0006, Validation Accuracy: 0.632200
# Epoch 199, CIFAR-10 Batch 1:  Loss:     0.0011, Validation Accuracy: 0.631400
# Epoch 199, CIFAR-10 Batch 2:  Loss:     0.0009, Validation Accuracy: 0.627200
# Epoch 199, CIFAR-10 Batch 3:  Loss:     0.0019, Validation Accuracy: 0.631000
# Epoch 199, CIFAR-10 Batch 4:  Loss:     0.0014, Validation Accuracy: 0.630800
# Epoch 199, CIFAR-10 Batch 5:  Loss:     0.0004, Validation Accuracy: 0.636000
# Epoch 200, CIFAR-10 Batch 1:  Loss:     0.0011, Validation Accuracy: 0.633400
# Epoch 200, CIFAR-10 Batch 2:  Loss:     0.0010, Validation Accuracy: 0.627800
# Epoch 200, CIFAR-10 Batch 3:  Loss:     0.0016, Validation Accuracy: 0.621400
# Epoch 200, CIFAR-10 Batch 4:  Loss:     0.0024, Validation Accuracy: 0.625000
# Epoch 200, CIFAR-10 Batch 5:  Loss:     0.0008, Validation Accuracy: 0.628000

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_test.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for test_feature_batch, test_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: test_feature_batch, loaded_y: test_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.63454669713974

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
